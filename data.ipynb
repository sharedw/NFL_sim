# %%
import nfl_data_py as nfl
import pandas as pd
pd.set_option('display.max_columns',30)

# %%
years=range(2010,2025)

# %%
weekly = nfl.import_weekly_data(years)
# Out:
# Downcasting floats.

# %%
weekly.to_csv('data/weekly.csv')
weekly.to_parquet('data/weekly.parquet')

# %%
weekly.loc[weekly.player_display_name=='Saquon Barkley'].sample(3)
# Out:
#        player_id player_name player_display_name position position_group  \
# 3313  00-0034844   S.Barkley      Saquon Barkley       RB             RB
# 5209  00-0034844   S.Barkley      Saquon Barkley       RB             RB
# 3315  00-0034844   S.Barkley      Saquon Barkley       RB             RB
#
#                                            headshot_url recent_team  season  \
# 3313  https://static.www.nfl.com/image/private/f_aut...         NYG    2021
# 5209  https://static.www.nfl.com/image/private/f_aut...         NYG    2018
# 3315  https://static.www.nfl.com/image/private/f_aut...         NYG    2021
#
#       week season_type opponent_team  completions  attempts  passing_yards  \
# 3313     3         REG           ATL            0         0            0.0
# 5209    15         REG           TEN            0         0            0.0
# 3315     5         REG           DAL            0         0            0.0
#
#       passing_tds  ...  receiving_tds  receiving_fumbles  \
# 3313            0  ...              0                0.0
# 5209            0  ...              0                0.0
# 3315            0  ...              0                0.0
#
#       receiving_fumbles_lost  receiving_air_yards  \
# 3313                     0.0                -17.0
# 5209                     0.0                  5.0
# 3315                     0.0                 10.0
#
#       receiving_yards_after_catch  receiving_first_downs  receiving_epa  \
# 3313                         65.0                    2.0       0.239892
# 5209                         15.0                    1.0      -3.852809
# 3315                          0.0                    0.0      -0.606139
#
#       receiving_2pt_conversions      racr  target_share  air_yards_share  \
# 3313                          0 -2.529412      0.200000        -0.071429
# 5209                          0  5.000000      0.227273         0.014409
# 3315                          0  0.000000      0.027027         0.025575
#
#           wopr  special_teams_tds  fantasy_points  fantasy_points_ppr
# 3313  0.250000                0.0            15.4                21.4
# 5209  0.350996                0.0             5.6                 9.6
# 3315  0.058443                0.0             0.9                 0.9
#
# [3 rows x 53 columns]

# %%
pbp = nfl.import_pbp_data(range(2010,2025))
pbp
# Out:
# 2010 done.
# 2011 done.
# 2012 done.
# 2013 done.
# 2014 done.
# 2015 done.
# 2016 done.
# 2017 done.
# 2018 done.
# 2019 done.
# 2020 done.
# 2021 done.
# 2022 done.
# 2023 done.
# 2024 done.
# Downcasting floats.
#         play_id          game_id old_game_id home_team away_team season_type  \
# 0           1.0  2010_01_ARI_STL  2010091208        LA       ARI         REG
# 1          36.0  2010_01_ARI_STL  2010091208        LA       ARI         REG
# 2          58.0  2010_01_ARI_STL  2010091208        LA       ARI         REG
# 3          82.0  2010_01_ARI_STL  2010091208        LA       ARI         REG
# 4         103.0  2010_01_ARI_STL  2010091208        LA       ARI         REG
# ...         ...              ...         ...       ...       ...         ...
# 705771   4546.0  2024_13_TEN_WAS  2024120106       WAS       TEN         REG
# 705772   4568.0  2024_13_TEN_WAS  2024120106       WAS       TEN         REG
# 705773   4597.0  2024_13_TEN_WAS  2024120106       WAS       TEN         REG
# 705774   4619.0  2024_13_TEN_WAS  2024120106       WAS       TEN         REG
# 705775   4641.0  2024_13_TEN_WAS  2024120106       WAS       TEN         REG
#
#         week posteam posteam_type defteam side_of_field  yardline_100  \
# 0          1    None         None    None          None           NaN
# 1          1     ARI         away      LA            LA          30.0
# 2          1     ARI         away      LA           ARI          78.0
# 3          1     ARI         away      LA           ARI          78.0
# 4          1     ARI         away      LA           ARI          73.0
# ...      ...     ...          ...     ...           ...           ...
# 705771    13     WAS         home     TEN           TEN          32.0
# 705772    13     WAS         home     TEN           TEN          27.0
# 705773    13     WAS         home     TEN           TEN          23.0
# 705774    13     WAS         home     TEN           TEN          19.0
# 705775    13     WAS         home     TEN          None           NaN
#
#          game_date  quarter_seconds_remaining  half_seconds_remaining  ...  \
# 0       2010-09-12                      900.0                  1800.0  ...
# 1       2010-09-12                      900.0                  1800.0  ...
# 2       2010-09-12                      895.0                  1795.0  ...
# 3       2010-09-12                      864.0                  1764.0  ...
# 4       2010-09-12                      823.0                  1723.0  ...
# ...            ...                        ...                     ...  ...
# 705771  2024-12-01                      159.0                   159.0  ...
# 705772  2024-12-01                      120.0                   120.0  ...
# 705773  2024-12-01                       74.0                    74.0  ...
# 705774  2024-12-01                       32.0                    32.0  ...
# 705775  2024-12-01                        0.0                     0.0  ...
#
#         offense_personnel defenders_in_box  defense_personnel  \
# 0                     NaN              NaN                NaN
# 1                     NaN              NaN                NaN
# 2                     NaN              NaN                NaN
# 3                     NaN              NaN                NaN
# 4                     NaN              NaN                NaN
# ...                   ...              ...                ...
# 705771                NaN              NaN                NaN
# 705772                NaN              NaN                NaN
# 705773                NaN              NaN                NaN
# 705774                NaN              NaN                NaN
# 705775                NaN              NaN                NaN
#
#         number_of_pass_rushers  players_on_play  offense_players  \
# 0                          NaN              NaN              NaN
# 1                          NaN              NaN              NaN
# 2                          NaN              NaN              NaN
# 3                          NaN              NaN              NaN
# 4                          NaN              NaN              NaN
# ...                        ...              ...              ...
# 705771                     NaN              NaN              NaN
# 705772                     NaN              NaN              NaN
# 705773                     NaN              NaN              NaN
# 705774                     NaN              NaN              NaN
# 705775                     NaN              NaN              NaN
#
#         defense_players  n_offense n_defense ngs_air_yards  time_to_throw  \
# 0                   NaN        NaN       NaN           NaN            NaN
# 1                   NaN        NaN       NaN           NaN            NaN
# 2                   NaN        NaN       NaN           NaN            NaN
# 3                   NaN        NaN       NaN           NaN            NaN
# 4                   NaN        NaN       NaN           NaN            NaN
# ...                 ...        ...       ...           ...            ...
# 705771              NaN        NaN       NaN           NaN            NaN
# 705772              NaN        NaN       NaN           NaN            NaN
# 705773              NaN        NaN       NaN           NaN            NaN
# 705774              NaN        NaN       NaN           NaN            NaN
# 705775              NaN        NaN       NaN           NaN            NaN
#
#         was_pressure route defense_man_zone_type  defense_coverage_type
# 0                NaN   NaN                   NaN                    NaN
# 1                NaN   NaN                   NaN                    NaN
# 2                NaN   NaN                   NaN                    NaN
# 3                NaN   NaN                   NaN                    NaN
# 4                NaN   NaN                   NaN                    NaN
# ...              ...   ...                   ...                    ...
# 705771           NaN   NaN                   NaN                    NaN
# 705772           NaN   NaN                   NaN                    NaN
# 705773           NaN   NaN                   NaN                    NaN
# 705774           NaN   NaN                   NaN                    NaN
# 705775           NaN   NaN                   NaN                    NaN
#
# [705776 rows x 392 columns]

# %%
pbp['temp'] = pbp['temp'].fillna(pbp.groupby('home_team')['temp'].transform('mean').round()).fillna(58)
pbp['wind'] = pbp['wind'].fillna(pbp.groupby('home_team')['wind'].transform('mean').round()).fillna(5)
pbp.loc[pbp.home_team == pbp.posteam, ['spread_line']] = pbp.loc[pbp.home_team == pbp.posteam, ['spread_line']] * -1 # favored is negative

# %%
pbp.to_csv('data/pbp.csv')

# %%
pbp.to_parquet('data/pbp.parquet')

# %%
rosters = nfl.import_weekly_rosters(range(2012,2024))
rosters
# Out:
#         season team position depth_chart_position jersey_number status  \
# 0         2012   SF        K                 None             2    ACT
# 1         2012   SF        K                 None             2    ACT
# 2         2012   SF        K                 None             2    ACT
# 3         2012   SF        K                 None             2    ACT
# 4         2012   SF        K                 None             2    ACT
# ...        ...  ...      ...                  ...           ...    ...
# 500244    2023  DEN       LB                   LB           NaN    DEV
# 500245    2023  DEN       LB                   LB           NaN    DEV
# 500246    2023  DEN       LB                   LB           NaN    DEV
# 500247    2023  DEN       LB                   LB           NaN    DEV
# 500248    2023  DEN       LB                   LB           NaN    DEV
#
#           player_name first_name last_name birth_date  height  weight college  \
# 0         David Akers      David     Akers 1974-12-09    70.0   200.0    None
# 1         David Akers      David     Akers 1974-12-09    70.0   200.0    None
# 2         David Akers      David     Akers 1974-12-09    70.0   200.0    None
# 3         David Akers      David     Akers 1974-12-09    70.0   200.0    None
# 4         David Akers      David     Akers 1974-12-09    70.0   200.0    None
# ...               ...        ...       ...        ...     ...     ...     ...
# 500244  Durell Nchami     Durell    Nchami        NaT     NaN   260.0    None
# 500245  Durell Nchami     Durell    Nchami        NaT     NaN   260.0    None
# 500246  Durell Nchami     Durell    Nchami        NaT     NaN   260.0    None
# 500247  Durell Nchami     Durell    Nchami        NaT     NaN   260.0    None
# 500248  Durell Nchami     Durell    Nchami        NaT     NaN   260.0    None
#
#          player_id espn_id  ... years_exp  \
# 0       00-0000108    None  ...      15.0
# 1       00-0000108    None  ...      15.0
# 2       00-0000108    None  ...      15.0
# 3       00-0000108    None  ...      15.0
# 4       00-0000108    None  ...      15.0
# ...            ...     ...  ...       ...
# 500244        None    None  ...       0.0
# 500245        None    None  ...       0.0
# 500246        None    None  ...       0.0
# 500247        None    None  ...       0.0
# 500248        None    None  ...       0.0
#
#                                              headshot_url ngs_position week  \
# 0       https://static.www.nfl.com/image/private/f_aut...         None   12
# 1       https://static.www.nfl.com/image/private/f_aut...         None   16
# 2       https://static.www.nfl.com/image/private/f_aut...         None    8
# 3       https://static.www.nfl.com/image/private/f_aut...         None    1
# 4       https://static.www.nfl.com/image/private/f_aut...         None   11
# ...                                                   ...          ...  ...
# 500244                                               None         None   18
# 500245                                               None         None   14
# 500246                                               None         None   15
# 500247                                               None         None   16
# 500248                                               None         None   17
#
#        game_type status_description_abbr football_name     esb_id gsis_it_id  \
# 0            REG                     A01         David  AKE551610       None
# 1            REG                     A01         David  AKE551610       None
# 2            REG                     A01         David  AKE551610       None
# 3            REG                     A01         David  AKE551610       None
# 4            REG                     A01         David  AKE551610       None
# ...          ...                     ...           ...        ...        ...
# 500244       REG                     P01        Durell  NCH415291      57034
# 500245       REG                     P01        Durell       None      57034
# 500246       REG                     P01        Durell  NCH415291      57034
# 500247       REG                     P01        Durell  NCH415291      57034
# 500248       REG                     P01        Durell  NCH415291      57034
#
#                                     smart_id  entry_year rookie_year  \
# 0       3200414b-4555-1610-e0e6-a72c82e419e7      1997.0      1997.0
# 1       3200414b-4555-1610-e0e6-a72c82e419e7      1997.0      1997.0
# 2       3200414b-4555-1610-e0e6-a72c82e419e7      1997.0      1997.0
# 3       3200414b-4555-1610-e0e6-a72c82e419e7      1997.0      1997.0
# 4       3200414b-4555-1610-e0e6-a72c82e419e7      1997.0      1997.0
# ...                                      ...         ...         ...
# 500244                                  None      2023.0      2023.0
# 500245                                  None      2023.0      2023.0
# 500246                                  None      2023.0      2023.0
# 500247                                  None      2023.0      2023.0
# 500248                                  None      2023.0      2023.0
#
#        draft_club draft_number     age
# 0            None         None  37.963
# 1            None         None  38.040
# 2            None         None  37.889
# 3            None         None  37.752
# 4            None         None  37.947
# ...           ...          ...     ...
# 500244       None          NaN     NaN
# 500245       None          NaN     NaN
# 500246       None          NaN     NaN
# 500247       None          NaN     NaN
# 500248       None          NaN     NaN
#
# [500249 rows x 37 columns]

# %%
ids = nfl.import_ids()

# %%
snaps = nfl.import_snap_counts(range(2012,2025))
team_map = {'OAK':'LV',
            'STL':'LA',
            'SD':'LAC'}
snaps['team'] = snaps['team'].apply(lambda x: team_map.get(x,x))

# %%
ids.loc[ids.gsis_id=='00-0032950']
# Out:
#       rotowire_id  db_season  fantasypros_id    espn_id     cbs_id  \
# 3153      10856.0       2024         15520.0  2573079.0  1907522.0
#
#       fantasy_data_id    merge_name  draft_round  yahoo_id  \
# 3153          17920.0  carson wentz          1.0   29236.0
#
#                  college  rotoworld_id twitter_username nfl_id  ktc_id  \
# 3153  North Dakota State       11257.0         cj_wentz    NaN     NaN
#
#       stats_id  ...    pfr_id  swish_id       cfbref_id  fleaflicker_id  \
# 3153   29236.0  ...  WentCa00  613866.0  carson-wentz-1             NaN
#
#       mfl_id                         sportradar_id   birthdate   age  \
# 3153   12610  e9a5c16b-4472-4be9-8030-3f77be7890cb  1992-12-30  31.9
#
#       sleeper_id  stats_global_id          name position  draft_year   pff_id  \
# 3153      3161.0         613866.0  Carson Wentz       QB      2016.0  10636.0
#
#       weight
# 3153   237.0
#
# [1 rows x 35 columns]

# %%
#get receiver ids from pbp with name like 'J.Coker' to fill gaps
receivers = pbp[['posteam','season','receiver_player_id', 'receiver_player_name']].dropna().drop_duplicates().copy().rename(
    {'posteam':'team','defteam':'opponent','receiver_player_id':'player_id', 'receiver_player_name':'abbr_name'},axis=1)
receivers['last_name']= receivers['abbr_name'].apply(lambda x: x.split('.')[-1])
#get rosters to fill most of the gaps
rosters = rosters.rename({'player_name':'player'},axis=1)
rosters_ids = rosters.loc[~rosters.player_id.isna()][['player', 'player_id','team','week','season']]
clean_snaps = snaps.merge(ids[['gsis_id','pfr_id','name']], left_on=['pfr_player_id'], right_on=['pfr_id']).dropna()
missing = snaps.merge(ids[['gsis_id','pfr_id','name']],how='left', left_on=['pfr_player_id'], right_on=['pfr_id'])
missing = missing[missing.isna().any(axis=1)].drop(['gsis_id','pfr_id','name'], axis=1)
with_rosters = missing.merge(rosters_ids, how='left').drop_duplicates()
clean_from_rosters = with_rosters.dropna()
#fill remaining gaps with pbp receiver ids from above
still_missing = with_rosters.loc[with_rosters.player_id.isna()].copy().drop(['player_id'],axis=1)
still_missing['last_name'] = still_missing['player'].apply(lambda x: ' '.join(x.split(' ')[1:]))
from_receivers = still_missing.merge(receivers, on=['team','season', 'last_name'], how='left').drop('abbr_name',axis=1)
clean_from_receivers = from_receivers.dropna()
still_missing = from_receivers.loc[from_receivers.player_id.isna()].copy()

# %%
final = pd.concat((clean_snaps, clean_from_rosters.rename({'player_id':'gsis_id'},axis=1)))
final = pd.concat((final, clean_from_receivers.rename({'player_id':'gsis_id'},axis=1)))
final = final.drop(['last_name','pfr_id','name'],axis=1)
final = final.rename({'team':'team_name'},axis=1).drop_duplicates()
final
# Out:
#                game_id   pfr_game_id  season game_type  week  \
# 0       2012_01_ATL_KC  201209090kan    2012       REG     1
# 1       2012_01_ATL_KC  201209090kan    2012       REG     1
# 2       2012_01_ATL_KC  201209090kan    2012       REG     1
# 3       2012_01_ATL_KC  201209090kan    2012       REG     1
# 4       2012_01_ATL_KC  201209090kan    2012       REG     1
# ...                ...           ...     ...       ...   ...
# 23304   2024_12_PHI_LA  202411240ram    2024       REG    12
# 23316  2024_12_PIT_CLE  202411210cle    2024       REG    12
# 23342    2024_12_SF_GB  202411240gnb    2024       REG    12
# 23380   2024_12_TB_NYG  202411240nyg    2024       REG    12
# 23408  2024_12_TEN_HOU  202411240htx    2024       REG    12
#
#                  player pfr_player_id position team_name opponent  \
# 0           Matt Cassel      CassMa00       QB        KC      ATL
# 1           Dwayne Bowe      BoweDw00       WR        KC      ATL
# 2      Dexter McCluster      McClDe00       WR        KC      ATL
# 3        Steve Breaston      BreaSt00       WR        KC      ATL
# 4           Tony Moeaki      MoeaTo00       TE        KC      ATL
# ...                 ...           ...      ...       ...      ...
# 23304    Ben VanSumeren      VanSBe00       LB       PHI       LA
# 23316  Blake Whiteheart      WhitBl01       TE       CLE      PIT
# 23342      Chris Brooks      BrooCh00       RB        GB       SF
# 23380       Ryan Miller      MillRy01       WR        TB      NYG
# 23408      Bryce Oliver      OlivBr02       WR       TEN      HOU
#
#        offense_snaps  offense_pct  defense_snaps  defense_pct  st_snaps  \
# 0               69.0         1.00            0.0          0.0       0.0
# 1               60.0         0.87            0.0          0.0       0.0
# 2               57.0         0.83            0.0          0.0       0.0
# 3               52.0         0.75            0.0          0.0       0.0
# 4               45.0         0.65            0.0          0.0       0.0
# ...              ...          ...            ...          ...       ...
# 23304            5.0         0.07            0.0          0.0      20.0
# 23316           10.0         0.17            0.0          0.0       7.0
# 23342           25.0         0.35            0.0          0.0       3.0
# 23380           15.0         0.23            0.0          0.0      13.0
# 23408           10.0         0.15            0.0          0.0       6.0
#
#        st_pct     gsis_id
# 0        0.00  00-0023662
# 1        0.00  00-0025410
# 2        0.00  00-0027651
# 3        0.00  00-0025529
# 4        0.00  00-0027695
# ...       ...         ...
# 23304    0.71  00-0038489
# 23316    0.35  00-0038710
# 23342    0.12  00-0038685
# 23380    0.65  00-0038824
# 23408    0.17  00-0039650
#
# [291970 rows x 17 columns]

# %%
final.to_csv('data/snap_counts.csv')

# %%
depth = nfl.import_depth_charts(years).drop_duplicates().reset_index(drop=True)

team_map = {'OAK':'LV',
            'STL':'LA',
            'SD':'LAC'}
depth['club_code'] = depth['club_code'].apply(lambda x: team_map.get(x,x))

depth = depth.sort_values(by=['season','club_code','week','depth_team'])
depth['dense_depth'] = depth.groupby(['club_code','season','week','position', 'game_type','formation']).cumcount()
depth['depth_position'] = depth['depth_position'].replace({'\n    ':None})
depth['depth_position'] = depth['depth_position'].fillna(depth['position'])
depth = depth.rename({'club_code':'team_name'},axis=1)
depth
# Out:
#         season team_name  week game_type depth_team   last_name first_name  \
# 25616     2010       ARI   1.0       REG          1       Brown       Levi
# 25617     2010       ARI   1.0       REG          1      Faneca       Alan
# 25618     2010       ARI   1.0       REG          1    Anderson      Derek
# 25619     2010       ARI   1.0       REG          1   Hightower    Timothy
# 25623     2010       ARI   1.0       REG          1  Fitzgerald      Larry
# ...        ...       ...   ...       ...        ...         ...        ...
# 534282    2024       WAS  13.0       REG          3     Driskel    Jeffrey
# 534283    2024       WAS  13.0       REG          3   McNichols     Jeremy
# 534293    2024       WAS  13.0       REG          3       Owens      Tyler
# 534294    2024       WAS  13.0       REG          3      Butler      Percy
# 534301    2024       WAS  13.0       REG          3     Sinnott        Ben
#
#        football_name formation     gsis_id jersey_number position   elias_id  \
# 25616           Levi   Offense  00-0025392            67        T  BRO548586
# 25617           Alan   Offense  00-0005058            66        G  FAN049971
# 25618          Derek   Offense  00-0023645             3       QB  AND180512
# 25619            Tim   Offense  00-0026289            22       RB  HIG784208
# 25623          Larry   Offense  00-0022921            11       WR  FIT437493
# ...              ...       ...         ...           ...      ...        ...
# 534282          Jeff   Offense  00-0032436            16       QB  DRI392790
# 534283        Jeremy   Offense  00-0033955            26       RB  MCN750971
# 534293         Tyler   Defense  00-0039681            40       SS  OWE797879
# 534294         Percy   Defense  00-0038100            35       FS  BUT505144
# 534301           Ben   Offense  00-0039912            82       TE  SIN713776
#
#        depth_position         full_name  dense_depth
# 25616              LT        Levi Brown          0.0
# 25617              LG       Alan Faneca          0.0
# 25618              QB    Derek Anderson          0.0
# 25619              RB     Tim Hightower          0.0
# 25623              WR  Larry Fitzgerald          0.0
# ...               ...               ...          ...
# 534282             QB      Jeff Driskel          2.0
# 534283             RB  Jeremy McNichols          2.0
# 534293             SS       Tyler Owens          1.0
# 534294             FS      Percy Butler          4.0
# 534301             TE       Ben Sinnott          2.0
#
# [537734 rows x 16 columns]

# %%
off = depth.copy()
off = off.merge(final, on=['gsis_id','week','season','game_type', 'position', 'team_name'], how='left')
#off['offense_snaps'] = off['offense_snaps'].fillna(0)
#off['offense_pct'] = off['offense_pct'].fillna(0)
off.loc[off.formation=='Offense'].sample(10)
# Out:
#         season team_name  week game_type depth_team   last_name first_name  \
# 136779    2013       MIN   8.0       REG          3     Freeman     Joshua
# 169291    2014        LV   8.0       REG          1    Ausberry      David
# 376297    2020       DEN  11.0       REG          1      Dotson      Demar
# 434155    2021        SF   2.0       REG          1      Samuel     Tyshun
# 513935    2024       ARI   4.0       REG          1     McBride       Trey
# 378908    2020        GB  20.0       CON          2     Jenkins     Elgton
# 157945    2014       CLE   8.0       REG          1       Greco       John
# 387945    2020       MIN   2.0       REG          2     Mannion       Sean
# 119171    2013       CHI   4.0       REG          1       Forte    Matthew
# 457300    2022        KC  17.0       REG          2  Allegretti   Nicholas
#
#        football_name formation     gsis_id jersey_number position   elias_id  \
# 136779          Josh   Offense  00-0026993             5       QB  FRE183259
# 169291         David   Offense  00-0028179            89       TE  AUS013223
# 376297         Demar   Offense  00-0026814            78        T  DOT277798
# 434155         Deebo   Offense  00-0035719             1       WR  SAM636097
# 513935          Trey   Offense  00-0037744            85       TE  MCB743360
# 378908        Elgton   Offense  00-0035526            74        G  JEN117507
# 157945          John   Offense  00-0026205            73        G  GRE029234
# 387945          Sean   Offense  00-0032245            15       QB  MAN548238
# 119171          Matt   Offense  00-0026184            22       RB  FOR645404
# 457300          Nick   Offense  00-0035149            67        G  ALL041653
#
#        depth_position        full_name  dense_depth          game_id  \
# 136779             QB     Josh Freeman          3.0              NaN
# 169291             TE   David Ausberry          0.0              NaN
# 376297             RT     Demar Dotson          1.0  2020_11_MIA_DEN
# 434155             WR     Deebo Samuel          1.0   2021_02_SF_PHI
# 513935             TE     Trey McBride          0.0              NaN
# 378908              C   Elgton Jenkins          4.0    2020_20_TB_GB
# 157945              C       John Greco          1.0              NaN
# 387945             QB     Sean Mannion          1.0              NaN
# 119171             RB       Matt Forte          0.0  2013_04_CHI_DET
# 457300             RG  Nick Allegretti          4.0   2022_17_DEN_KC
#
#          pfr_game_id           player pfr_player_id opponent  offense_snaps  \
# 136779           NaN              NaN           NaN      NaN            NaN
# 169291           NaN              NaN           NaN      NaN            NaN
# 376297  202011220den     Demar Dotson      DotsDe00      MIA           65.0
# 434155  202109190phi     Deebo Samuel      SamuDe00      PHI           49.0
# 513935           NaN              NaN           NaN      NaN            NaN
# 378908  202101240gnb   Elgton Jenkins      JenkEl00       TB           71.0
# 157945           NaN              NaN           NaN      NaN            NaN
# 387945           NaN              NaN           NaN      NaN            NaN
# 119171  201309290det       Matt Forte      FortMa00      DET           71.0
# 457300  202301010kan  Nick Allegretti      AlleNi00      DEN           19.0
#
#         offense_pct  defense_snaps  defense_pct  st_snaps  st_pct
# 136779          NaN            NaN          NaN       NaN     NaN
# 169291          NaN            NaN          NaN       NaN     NaN
# 376297         1.00            0.0          0.0       0.0    0.00
# 434155         0.70            0.0          0.0       0.0    0.00
# 513935          NaN            NaN          NaN       NaN     NaN
# 378908         1.00            0.0          0.0       4.0    0.15
# 157945          NaN            NaN          NaN       NaN     NaN
# 387945          NaN            NaN          NaN       NaN     NaN
# 119171         0.99            0.0          0.0       0.0    0.00
# 457300         0.32            0.0          0.0       5.0    0.17

# %%
off.to_csv('data/depth.csv')

# %%
sched = nfl.import_schedules([2024])
sched
# Out:
#               game_id  season game_type  week     gameday   weekday gametime  \
# 6706   2024_01_BAL_KC    2024       REG     1  2024-09-05  Thursday    20:20
# 6707   2024_01_GB_PHI    2024       REG     1  2024-09-06    Friday    20:15
# 6708  2024_01_PIT_ATL    2024       REG     1  2024-09-08    Sunday    13:00
# 6709  2024_01_ARI_BUF    2024       REG     1  2024-09-08    Sunday    13:00
# 6710  2024_01_TEN_CHI    2024       REG     1  2024-09-08    Sunday    13:00
# ...               ...     ...       ...   ...         ...       ...      ...
# 6973  2024_18_MIA_NYJ    2024       REG    18  2025-01-05    Sunday    13:00
# 6974  2024_18_NYG_PHI    2024       REG    18  2025-01-05    Sunday    13:00
# 6975  2024_18_CIN_PIT    2024       REG    18  2025-01-05    Sunday    13:00
# 6976    2024_18_NO_TB    2024       REG    18  2025-01-05    Sunday    13:00
# 6977  2024_18_HOU_TEN    2024       REG    18  2025-01-05    Sunday    13:00
#
#      away_team  away_score home_team  home_score location  result  total  \
# 6706       BAL        20.0        KC        27.0     Home     7.0   47.0
# 6707        GB        29.0       PHI        34.0  Neutral     5.0   63.0
# 6708       PIT        18.0       ATL        10.0     Home    -8.0   28.0
# 6709       ARI        28.0       BUF        34.0     Home     6.0   62.0
# 6710       TEN        17.0       CHI        24.0     Home     7.0   41.0
# ...        ...         ...       ...         ...      ...     ...    ...
# 6973       MIA         NaN       NYJ         NaN     Home     NaN    NaN
# 6974       NYG         NaN       PHI         NaN     Home     NaN    NaN
# 6975       CIN         NaN       PIT         NaN     Home     NaN    NaN
# 6976        NO         NaN        TB         NaN     Home     NaN    NaN
# 6977       HOU         NaN       TEN         NaN     Home     NaN    NaN
#
#       overtime  ...  over_odds  div_game      roof    surface  temp  wind  \
# 6706       0.0  ...     -110.0         0  outdoors      grass  67.0   8.0
# 6707       0.0  ...     -108.0         0  outdoors        NaN   NaN   NaN
# 6708       0.0  ...     -105.0         0    closed  fieldturf   NaN   NaN
# 6709       0.0  ...     -108.0         0  outdoors     a_turf  61.0  20.0
# 6710       0.0  ...     -110.0         0  outdoors      grass  67.0   8.0
# ...        ...  ...        ...       ...       ...        ...   ...   ...
# 6973       NaN  ...        NaN         1  outdoors  fieldturf   NaN   NaN
# 6974       NaN  ...        NaN         1  outdoors      grass   NaN   NaN
# 6975       NaN  ...        NaN         1  outdoors      grass   NaN   NaN
# 6976       NaN  ...        NaN         1  outdoors      grass   NaN   NaN
# 6977       NaN  ...        NaN         1  outdoors      grass   NaN   NaN
#
#       away_qb_id  home_qb_id   away_qb_name     home_qb_name       away_coach  \
# 6706  00-0034796  00-0033873  Lamar Jackson  Patrick Mahomes    John Harbaugh
# 6707  00-0036264  00-0036389    Jordan Love      Jalen Hurts     Matt LaFleur
# 6708  00-0036945  00-0029604  Justin Fields     Kirk Cousins      Mike Tomlin
# 6709  00-0035228  00-0034857   Kyler Murray       Josh Allen  Jonathan Gannon
# 6710  00-0039152  00-0039918     Will Levis   Caleb Williams   Brian Callahan
# ...          ...         ...            ...              ...              ...
# 6973         NaN         NaN            NaN              NaN    Mike McDaniel
# 6974         NaN         NaN            NaN              NaN     Brian Daboll
# 6975         NaN         NaN            NaN              NaN       Zac Taylor
# 6976         NaN         NaN            NaN              NaN     Dennis Allen
# 6977         NaN         NaN            NaN              NaN     DeMeco Ryans
#
#           home_coach        referee  stadium_id  \
# 6706       Andy Reid  Shawn Hochuli       KAN00
# 6707   Nick Sirianni    Ron Torbert       SAO00
# 6708   Raheem Morris    Brad Rogers       ATL97
# 6709  Sean McDermott      Tra Blake       BUF00
# 6710   Matt Eberflus    Shawn Smith       CHI98
# ...              ...            ...         ...
# 6973    Robert Saleh            NaN       NYC01
# 6974   Nick Sirianni            NaN       PHI00
# 6975     Mike Tomlin            NaN       PIT00
# 6976     Todd Bowles            NaN       TAM00
# 6977  Brian Callahan            NaN       NAS00
#
#                               stadium
# 6706  GEHA Field at Arrowhead Stadium
# 6707                Arena Corinthians
# 6708            Mercedes-Benz Stadium
# 6709                    New Era Field
# 6710                    Soldier Field
# ...                               ...
# 6973                  MetLife Stadium
# 6974          Lincoln Financial Field
# 6975                 Acrisure Stadium
# 6976            Raymond James Stadium
# 6977                   Nissan Stadium
#
# [272 rows x 46 columns]

# %%
week12 = sched.loc[sched.week == 12][
    [
        "game_id",
        "season",
        "week",
        'home_team',
        'away_team',
        "home_moneyline",
        "spread_line",
        "total_line",
        "temp",
        "wind",
    ]
]

# %%
sched['temp'] = sched['temp'].fillna(50)
sched['wind'] = sched['wind'].fillna(8)

# %%
sched.loc[sched.week == 13][[
        "game_id",
        "season",
        "week",
        'home_team',
        'away_team',
        "home_moneyline",
        "spread_line",
        "total_line",
        "temp",
        "wind",
    ]
].to_csv('week_13.csv')
