# %%
import nfl_data_py as nfl
import pandas as pd
pd.set_option('display.max_columns',30)

# %%
years=range(2010,2025)

# %%
weekly = nfl.import_weekly_data(years)
# Out:
# Downcasting floats.

# %%
weekly.to_csv('data/weekly.csv')
weekly.to_parquet('data/weekly.parquet')

# %%
weekly.loc[weekly.player_display_name=='Saquon Barkley'].sample(3)
# Out:
#        player_id player_name player_display_name position position_group  \
# 3313  00-0034844   S.Barkley      Saquon Barkley       RB             RB
# 5209  00-0034844   S.Barkley      Saquon Barkley       RB             RB
# 3315  00-0034844   S.Barkley      Saquon Barkley       RB             RB
#
#                                            headshot_url recent_team  season  \
# 3313  https://static.www.nfl.com/image/private/f_aut...         NYG    2021
# 5209  https://static.www.nfl.com/image/private/f_aut...         NYG    2018
# 3315  https://static.www.nfl.com/image/private/f_aut...         NYG    2021
#
#       week season_type opponent_team  completions  attempts  passing_yards  \
# 3313     3         REG           ATL            0         0            0.0
# 5209    15         REG           TEN            0         0            0.0
# 3315     5         REG           DAL            0         0            0.0
#
#       passing_tds  ...  receiving_tds  receiving_fumbles  \
# 3313            0  ...              0                0.0
# 5209            0  ...              0                0.0
# 3315            0  ...              0                0.0
#
#       receiving_fumbles_lost  receiving_air_yards  \
# 3313                     0.0                -17.0
# 5209                     0.0                  5.0
# 3315                     0.0                 10.0
#
#       receiving_yards_after_catch  receiving_first_downs  receiving_epa  \
# 3313                         65.0                    2.0       0.239892
# 5209                         15.0                    1.0      -3.852809
# 3315                          0.0                    0.0      -0.606139
#
#       receiving_2pt_conversions      racr  target_share  air_yards_share  \
# 3313                          0 -2.529412      0.200000        -0.071429
# 5209                          0  5.000000      0.227273         0.014409
# 3315                          0  0.000000      0.027027         0.025575
#
#           wopr  special_teams_tds  fantasy_points  fantasy_points_ppr
# 3313  0.250000                0.0            15.4                21.4
# 5209  0.350996                0.0             5.6                 9.6
# 3315  0.058443                0.0             0.9                 0.9
#
# [3 rows x 53 columns]

# %%
nfl.see_weekly_cols()
# Out:
# Index(['player_id', 'player_name', 'player_display_name', 'position',
#        'position_group', 'headshot_url', 'recent_team', 'season', 'week',
#        'season_type', 'opponent_team', 'completions', 'attempts',
#        'passing_yards', 'passing_tds', 'interceptions', 'sacks', 'sack_yards',
#        'sack_fumbles', 'sack_fumbles_lost', 'passing_air_yards',
#        'passing_yards_after_catch', 'passing_first_downs', 'passing_epa',
#        'passing_2pt_conversions', 'pacr', 'dakota', 'carries', 'rushing_yards',
#        'rushing_tds', 'rushing_fumbles', 'rushing_fumbles_lost',
#        'rushing_first_downs', 'rushing_epa', 'rushing_2pt_conversions',
#        'receptions', 'targets', 'receiving_yards', 'receiving_tds',
#        'receiving_fumbles', 'receiving_fumbles_lost', 'receiving_air_yards',
#        'receiving_yards_after_catch', 'receiving_first_downs', 'receiving_epa',
#        'receiving_2pt_conversions', 'racr', 'target_share', 'air_yards_share',
#        'wopr', 'special_teams_tds', 'fantasy_points', 'fantasy_points_ppr'],
#       dtype='object')

# %%
nfl.import_seasonal_data([2024]).columns
# Out:
# Index(['player_id', 'season', 'season_type', 'completions', 'attempts',
#        'passing_yards', 'passing_tds', 'interceptions', 'sacks', 'sack_yards',
#        'sack_fumbles', 'sack_fumbles_lost', 'passing_air_yards',
#        'passing_yards_after_catch', 'passing_first_downs', 'passing_epa',
#        'passing_2pt_conversions', 'pacr', 'dakota', 'carries', 'rushing_yards',
#        'rushing_tds', 'rushing_fumbles', 'rushing_fumbles_lost',
#        'rushing_first_downs', 'rushing_epa', 'rushing_2pt_conversions',
#        'receptions', 'targets', 'receiving_yards', 'receiving_tds',
#        'receiving_fumbles', 'receiving_fumbles_lost', 'receiving_air_yards',
#        'receiving_yards_after_catch', 'receiving_first_downs', 'receiving_epa',
#        'receiving_2pt_conversions', 'racr', 'target_share', 'air_yards_share',
#        'wopr_x', 'special_teams_tds', 'fantasy_points', 'fantasy_points_ppr',
#        'games', 'tgt_sh', 'ay_sh', 'yac_sh', 'wopr_y', 'ry_sh', 'rtd_sh',
#        'rfd_sh', 'rtdfd_sh', 'dom', 'w8dom', 'yptmpa', 'ppr_sh'],
#       dtype='object')

# %%
roster = nfl.import_depth_charts([2024])
roster
# Out:
#        season club_code  week game_type depth_team  last_name first_name  \
# 0        2024       ATL     1       REG          1   Onyemata      David
# 1        2024       ATL     1       REG          2     Graham    Ta'Quon
# 2        2024       ATL     1       REG          2   Ebiketie     Arnold
# 3        2024       ATL     1       REG          2  Abernathy      Micah
# 4        2024       ATL     1       REG          2   Phillips      Clark
# ...       ...       ...   ...       ...        ...        ...        ...
# 20319    2024       HOU    11       REG          1   Townsend      Tommy
# 20320    2024       HOU    11       REG          1      Weeks   Jonathan
# 20321    2024       HOU    11       REG          1   Townsend      Tommy
# 20322    2024       HOU    11       REG          1       Sims     Steven
# 20323    2024       HOU    11       REG          2       Sims     Steven
#
#       football_name      formation     gsis_id jersey_number position  \
# 0             David        Defense  00-0033051            90       DT
# 1           Ta'Quon        Defense  00-0036948            95       DE
# 2            Arnold        Defense  00-0038116            17      OLB
# 3             Micah        Defense  00-0035098            29       FS
# 4             Clark        Defense  00-0038568            22       CB
# ...             ...            ...         ...           ...      ...
# 20319         Tommy  Special Teams  00-0035889             6        P
# 20320      Jonathan  Special Teams  00-0027224            46       LS
# 20321         Tommy  Special Teams  00-0035889             6        P
# 20322        Steven  Special Teams  00-0034928            82       WR
# 20323        Steven  Special Teams  00-0034928            82       WR
#
#         elias_id depth_position        full_name
# 0      ONY164481             DL   David Onyemata
# 1      GRA243423             DL   Ta'Quon Graham
# 2      EBI415291            OLB  Arnold Ebiketie
# 3      ABE643008              S  Micah Abernathy
# 4      PHI672138             CB   Clark Phillips
# ...          ...            ...              ...
# 20319  TOW774004              P   Tommy Townsend
# 20320  WEE504348             LS   Jonathan Weeks
# 20321  TOW774004              H   Tommy Townsend
# 20322  SIM809106             PR      Steven Sims
# 20323  SIM809106             KR      Steven Sims
#
# [20324 rows x 15 columns]

# %%
roster.loc[(roster.full_name.str.contains('Bucky')) & 
           (roster.formation=='Offense')][[x for x in roster.columns if '_id' not in x]]
# Out:
#        season club_code  week game_type depth_team last_name first_name  \
# 16641    2024        TB     1       REG          3    Irving  Mar'Keise
# 16703    2024        TB     2       REG          3    Irving  Mar'Keise
# 16782    2024        TB     3       REG          3    Irving  Mar'Keise
# 16816    2024        TB     4       REG          3    Irving  Mar'Keise
# 16907    2024        TB     5       REG          3    Irving  Mar'Keise
# 16956    2024        TB     6       REG          2    Irving  Mar'Keise
# 17021    2024        TB     7       REG          2    Irving  Mar'Keise
# 17070    2024        TB     8       REG          2    Irving  Mar'Keise
# 17144    2024        TB     9       REG          2    Irving  Mar'Keise
# 17205    2024        TB    10       REG          2    Irving  Mar'Keise
# 17237    2024        TB    11       REG          2    Irving  Mar'Keise
#
#       football_name formation jersey_number position depth_position  \
# 16641         Bucky   Offense             7       RB             RB
# 16703         Bucky   Offense             7       RB             RB
# 16782         Bucky   Offense             7       RB             RB
# 16816         Bucky   Offense             7       RB             RB
# 16907         Bucky   Offense             7       RB             RB
# 16956         Bucky   Offense             7       RB             RB
# 17021         Bucky   Offense             7       RB             RB
# 17070         Bucky   Offense             7       RB             RB
# 17144         Bucky   Offense             7       RB             RB
# 17205         Bucky   Offense             7       RB             RB
# 17237         Bucky   Offense             7       RB             RB
#
#           full_name
# 16641  Bucky Irving
# 16703  Bucky Irving
# 16782  Bucky Irving
# 16816  Bucky Irving
# 16907  Bucky Irving
# 16956  Bucky Irving
# 17021  Bucky Irving
# 17070  Bucky Irving
# 17144  Bucky Irving
# 17205  Bucky Irving
# 17237  Bucky Irving

# %%
nfl.import_sc_lines([2020])
# Out:
#       season  week away_team home_team     game_id side  line
# 3584    2020     1       HOU        KC  2020091000  HOU   9.0
# 3585    2020     1       HOU        KC  2020091000   KC  -9.0
# 3586    2020     1       SEA       ATL  2020091300  ATL   2.5
# 3587    2020     1       SEA       ATL  2020091300  SEA  -2.5
# 3588    2020     1       CLE       BAL  2020091301  BAL  -8.0
# ...      ...   ...       ...       ...         ...  ...   ...
# 4087    2020    17       JAX       IND  2021010313  JAX  14.0
# 4088    2020    17       ARI        LA  2021010314  ARI  -2.5
# 4089    2020    17       ARI        LA  2021010314   LA   2.5
# 4090    2020    17       SEA        SF  2021010315  SEA  -6.0
# 4091    2020    17       SEA        SF  2021010315   SF   6.0
#
# [508 rows x 7 columns]

# %%
nfl.import_schedules(years)
# Out:
#               game_id  season game_type  week     gameday   weekday gametime  \
# 6706   2024_01_BAL_KC    2024       REG     1  2024-09-05  Thursday    20:20
# 6707   2024_01_GB_PHI    2024       REG     1  2024-09-06    Friday    20:15
# 6708  2024_01_PIT_ATL    2024       REG     1  2024-09-08    Sunday    13:00
# 6709  2024_01_ARI_BUF    2024       REG     1  2024-09-08    Sunday    13:00
# 6710  2024_01_TEN_CHI    2024       REG     1  2024-09-08    Sunday    13:00
# ...               ...     ...       ...   ...         ...       ...      ...
# 6973  2024_18_MIA_NYJ    2024       REG    18  2025-01-05    Sunday    13:00
# 6974  2024_18_NYG_PHI    2024       REG    18  2025-01-05    Sunday    13:00
# 6975  2024_18_CIN_PIT    2024       REG    18  2025-01-05    Sunday    13:00
# 6976    2024_18_NO_TB    2024       REG    18  2025-01-05    Sunday    13:00
# 6977  2024_18_HOU_TEN    2024       REG    18  2025-01-05    Sunday    13:00
#
#      away_team  away_score home_team  ...  wind  away_qb_id  home_qb_id  \
# 6706       BAL        20.0        KC  ...   8.0  00-0034796  00-0033873
# 6707        GB        29.0       PHI  ...   NaN  00-0036264  00-0036389
# 6708       PIT        18.0       ATL  ...   NaN  00-0036945  00-0029604
# 6709       ARI        28.0       BUF  ...  20.0  00-0035228  00-0034857
# 6710       TEN        17.0       CHI  ...   8.0  00-0039152  00-0039918
# ...        ...         ...       ...  ...   ...         ...         ...
# 6973       MIA         NaN       NYJ  ...   NaN         NaN         NaN
# 6974       NYG         NaN       PHI  ...   NaN         NaN         NaN
# 6975       CIN         NaN       PIT  ...   NaN         NaN         NaN
# 6976        NO         NaN        TB  ...   NaN         NaN         NaN
# 6977       HOU         NaN       TEN  ...   NaN         NaN         NaN
#
#        away_qb_name     home_qb_name       away_coach      home_coach  \
# 6706  Lamar Jackson  Patrick Mahomes    John Harbaugh       Andy Reid
# 6707    Jordan Love      Jalen Hurts     Matt LaFleur   Nick Sirianni
# 6708  Justin Fields     Kirk Cousins      Mike Tomlin   Raheem Morris
# 6709   Kyler Murray       Josh Allen  Jonathan Gannon  Sean McDermott
# 6710     Will Levis   Caleb Williams   Brian Callahan   Matt Eberflus
# ...             ...              ...              ...             ...
# 6973            NaN              NaN    Mike McDaniel    Robert Saleh
# 6974            NaN              NaN     Brian Daboll   Nick Sirianni
# 6975            NaN              NaN       Zac Taylor     Mike Tomlin
# 6976            NaN              NaN     Dennis Allen     Todd Bowles
# 6977            NaN              NaN     DeMeco Ryans  Brian Callahan
#
#             referee stadium_id                          stadium
# 6706  Shawn Hochuli      KAN00  GEHA Field at Arrowhead Stadium
# 6707    Ron Torbert      SAO00                Arena Corinthians
# 6708    Brad Rogers      ATL97            Mercedes-Benz Stadium
# 6709      Tra Blake      BUF00                    New Era Field
# 6710    Shawn Smith      CHI98                    Soldier Field
# ...             ...        ...                              ...
# 6973            NaN      NYC01                  MetLife Stadium
# 6974            NaN      PHI00          Lincoln Financial Field
# 6975            NaN      PIT00                 Acrisure Stadium
# 6976            NaN      TAM00            Raymond James Stadium
# 6977            NaN      NAS00                   Nissan Stadium
#
# [272 rows x 46 columns]

# %%
pbp = nfl.import_pbp_data(range(2010,2025))
pbp
# Out:
# 2010 done.
# 2011 done.
# 2012 done.
# 2013 done.
# 2014 done.
# 2015 done.
# 2016 done.
# 2017 done.
# 2018 done.
# 2019 done.
# 2020 done.
# 2021 done.
# 2022 done.
# 2023 done.
# 2024 done.
# Downcasting floats.
#         play_id          game_id old_game_id home_team away_team season_type  \
# 0           1.0  2010_01_ARI_STL  2010091208        LA       ARI         REG
# 1          36.0  2010_01_ARI_STL  2010091208        LA       ARI         REG
# 2          58.0  2010_01_ARI_STL  2010091208        LA       ARI         REG
# 3          82.0  2010_01_ARI_STL  2010091208        LA       ARI         REG
# 4         103.0  2010_01_ARI_STL  2010091208        LA       ARI         REG
# ...         ...              ...         ...       ...       ...         ...
# 700837   4266.0  2024_11_WAS_PHI  2024111400       PHI       WAS         REG
# 700838   4317.0  2024_11_WAS_PHI  2024111400       PHI       WAS         REG
# 700839   4286.0  2024_11_WAS_PHI  2024111400       PHI       WAS         REG
# 700840   4334.0  2024_11_WAS_PHI  2024111400       PHI       WAS         REG
# 700841   4356.0  2024_11_WAS_PHI  2024111400       PHI       WAS         REG
#
#         week posteam posteam_type defteam side_of_field  yardline_100  \
# 0          1    None         None    None          None           NaN
# 1          1     ARI         away      LA            LA          30.0
# 2          1     ARI         away      LA           ARI          78.0
# 3          1     ARI         away      LA           ARI          78.0
# 4          1     ARI         away      LA           ARI          73.0
# ...      ...     ...          ...     ...           ...           ...
# 700837    11     WAS         away     PHI           PHI           2.0
# 700838    11    None         None    None          None           NaN
# 700839    11     PHI         home     WAS           WAS          35.0
# 700840    11     PHI         home     WAS           WAS          47.0
# 700841    11     PHI         home     WAS          None           NaN
#
#          game_date  quarter_seconds_remaining  half_seconds_remaining  ...  \
# 0       2010-09-12                      900.0                  1800.0  ...
# 1       2010-09-12                      900.0                  1800.0  ...
# 2       2010-09-12                      895.0                  1795.0  ...
# 3       2010-09-12                      864.0                  1764.0  ...
# 4       2010-09-12                      823.0                  1723.0  ...
# ...            ...                        ...                     ...  ...
# 700837  2024-11-14                       28.0                    28.0  ...
# 700838  2024-11-14                       28.0                    28.0  ...
# 700839  2024-11-14                       28.0                    28.0  ...
# 700840  2024-11-14                       27.0                    27.0  ...
# 700841  2024-11-14                        0.0                     0.0  ...
#
#         offense_personnel defenders_in_box  defense_personnel  \
# 0                     NaN              NaN                NaN
# 1                     NaN              NaN                NaN
# 2                     NaN              NaN                NaN
# 3                     NaN              NaN                NaN
# 4                     NaN              NaN                NaN
# ...                   ...              ...                ...
# 700837                NaN              NaN                NaN
# 700838                NaN              NaN                NaN
# 700839                NaN              NaN                NaN
# 700840                NaN              NaN                NaN
# 700841                NaN              NaN                NaN
#
#         number_of_pass_rushers  players_on_play  offense_players  \
# 0                          NaN              NaN              NaN
# 1                          NaN              NaN              NaN
# 2                          NaN              NaN              NaN
# 3                          NaN              NaN              NaN
# 4                          NaN              NaN              NaN
# ...                        ...              ...              ...
# 700837                     NaN              NaN              NaN
# 700838                     NaN              NaN              NaN
# 700839                     NaN              NaN              NaN
# 700840                     NaN              NaN              NaN
# 700841                     NaN              NaN              NaN
#
#         defense_players  n_offense n_defense ngs_air_yards  time_to_throw  \
# 0                   NaN        NaN       NaN           NaN            NaN
# 1                   NaN        NaN       NaN           NaN            NaN
# 2                   NaN        NaN       NaN           NaN            NaN
# 3                   NaN        NaN       NaN           NaN            NaN
# 4                   NaN        NaN       NaN           NaN            NaN
# ...                 ...        ...       ...           ...            ...
# 700837              NaN        NaN       NaN           NaN            NaN
# 700838              NaN        NaN       NaN           NaN            NaN
# 700839              NaN        NaN       NaN           NaN            NaN
# 700840              NaN        NaN       NaN           NaN            NaN
# 700841              NaN        NaN       NaN           NaN            NaN
#
#         was_pressure route defense_man_zone_type  defense_coverage_type
# 0                NaN   NaN                   NaN                    NaN
# 1                NaN   NaN                   NaN                    NaN
# 2                NaN   NaN                   NaN                    NaN
# 3                NaN   NaN                   NaN                    NaN
# 4                NaN   NaN                   NaN                    NaN
# ...              ...   ...                   ...                    ...
# 700837           NaN   NaN                   NaN                    NaN
# 700838           NaN   NaN                   NaN                    NaN
# 700839           NaN   NaN                   NaN                    NaN
# 700840           NaN   NaN                   NaN                    NaN
# 700841           NaN   NaN                   NaN                    NaN
#
# [700842 rows x 392 columns]

# %%
pbp.to_csv('data/pbp.csv')

# %%
pbp.to_parquet('data/pbp.parquet')

# %%
nfl.import_injuries([2024])
# Out:
#       season game_type team  week     gsis_id position          full_name  \
# 0       2024       REG  ARI     1  00-0035629        T     Jonah Williams
# 1       2024       REG  ARI     1  00-0039521       WR      Xavier Weaver
# 2       2024       REG  ARI     1  00-0037141        S        Joey Blount
# 3       2024       REG  ARI     1  00-0039737       TE         Tip Reiman
# 4       2024       REG  ATL     1  00-0031583       DT      Grady Jarrett
# ...      ...       ...  ...   ...         ...      ...                ...
# 3549    2024       REG  WAS    11  00-0033874       CB  Marshon Lattimore
# 3550    2024       REG  WAS    11  00-0035145        K     Austin Seibert
# 3551    2024       REG  WAS    11  00-0039913        T    Brandon Coleman
# 3552    2024       REG  WAS    11  00-0030725        T    Cornelius Lucas
# 3553    2024       REG  WAS    11  00-0033831        T       Andrew Wylie
#
#      first_name  last_name report_primary_injury report_secondary_injury  \
# 0         Jonah   Williams                  Knee                    None
# 1        Xavier     Weaver               Oblique                    None
# 2          Joey     Blount                  Back                    None
# 3           Tip     Reiman                 Ankle                    None
# 4         Grady    Jarrett                  None                    None
# ...         ...        ...                   ...                     ...
# 3549    Marshon  Lattimore             Hamstring                    None
# 3550     Austin    Seibert             Right Hip                    None
# 3551    Brandon    Coleman              Shoulder                    None
# 3552  Cornelius      Lucas                 Ankle                    None
# 3553     Andrew      Wylie              Shoulder                    None
#
#      report_status              practice_primary_injury  \
# 0              Out                                 None
# 1              Out                              Oblique
# 2     Questionable                                 Back
# 3     Questionable                                Ankle
# 4             None  Not injury related - resting player
# ...            ...                                  ...
# 3549           Out                            Hamstring
# 3550           Out                            Right Hip
# 3551  Questionable                             Shoulder
# 3552  Questionable                                Ankle
# 3553  Questionable                             Shoulder
#
#      practice_secondary_injury                    practice_status  \
# 0                         None                             \n
# 1                         None    Did Not Participate In Practice
# 2                         None  Limited Participation in Practice
# 3                         None  Limited Participation in Practice
# 4                         None    Did Not Participate In Practice
# ...                        ...                                ...
# 3549                      None    Did Not Participate In Practice
# 3550                      None    Did Not Participate In Practice
# 3551                      None  Limited Participation in Practice
# 3552                      None  Limited Participation in Practice
# 3553                      None  Limited Participation in Practice
#
#                  date_modified
# 0    2024-09-08 18:35:57+00:00
# 1    2024-09-06 19:05:30+00:00
# 2    2024-09-06 19:05:21+00:00
# 3    2024-09-06 19:05:21+00:00
# 4    2024-09-06 18:35:04+00:00
# ...                        ...
# 3549 2024-11-13 18:32:37+00:00
# 3550 2024-11-13 18:32:54+00:00
# 3551 2024-11-13 18:32:06+00:00
# 3552 2024-11-13 18:32:06+00:00
# 3553 2024-11-13 18:32:06+00:00
#
# [3554 rows x 16 columns]

# %%
depth = nfl.import_depth_charts(years).drop_duplicates().reset_index(drop=True)

# %%
team_map = {'OAK':'LV',
            'STL':'LA',
            'SD':'LAC'}
depth['club_code'] = depth['club_code'].apply(lambda x: team_map.get(x,x))

# %%
depth = depth.sort_values(by=['season','club_code','week','depth_team'])
depth['dense_depth'] = depth.groupby(['club_code','season','week','position', 'game_type','formation']).cumcount()
depth['depth_position'] = depth['depth_position'].replace({'\n    ':None})
depth['depth_position'] = depth['depth_position'].fillna(depth['position'])
depth = depth.rename({'club_code':'team_name'},axis=1)
depth
# Out:
#         season team_name  week game_type depth_team   last_name   first_name  \
# 25616     2010       ARI   1.0       REG          1       Brown         Levi
# 25617     2010       ARI   1.0       REG          1      Faneca         Alan
# 25618     2010       ARI   1.0       REG          1    Anderson        Derek
# 25619     2010       ARI   1.0       REG          1   Hightower      Timothy
# 25623     2010       ARI   1.0       REG          1  Fitzgerald        Larry
# ...        ...       ...   ...       ...        ...         ...          ...
# 533113    2024       WAS  12.0       REG          3     Bellore         Nick
# 533128    2024       WAS  12.0       REG          3   Rodriguez  Christopher
# 533143    2024       WAS  12.0       REG          3     Driskel      Jeffrey
# 533144    2024       WAS  12.0       REG          3   McNichols       Jeremy
# 533162    2024       WAS  12.0       REG          3     Sinnott          Ben
#
#        football_name formation     gsis_id jersey_number position   elias_id  \
# 25616           Levi   Offense  00-0025392            67        T  BRO548586
# 25617           Alan   Offense  00-0005058            66        G  FAN049971
# 25618          Derek   Offense  00-0023645             3       QB  AND180512
# 25619            Tim   Offense  00-0026289            22       RB  HIG784208
# 25623          Larry   Offense  00-0022921            11       WR  FIT437493
# ...              ...       ...         ...           ...      ...        ...
# 533113          Nick   Defense  00-0028292            57      ILB  BEL740458
# 533128         Chris   Offense  00-0038611            36       RB  ROD797090
# 533143          Jeff   Offense  00-0032436            16       QB  DRI392790
# 533144        Jeremy   Offense  00-0033955            26       RB  MCN750971
# 533162           Ben   Offense  00-0039912            82       TE  SIN713776
#
#        depth_position         full_name  dense_depth
# 25616              LT        Levi Brown          0.0
# 25617              LG       Alan Faneca          0.0
# 25618              QB    Derek Anderson          0.0
# 25619              RB     Tim Hightower          0.0
# 25623              WR  Larry Fitzgerald          0.0
# ...               ...               ...          ...
# 533113            OLB      Nick Bellore          3.0
# 533128             RB   Chris Rodriguez          2.0
# 533143             QB      Jeff Driskel          2.0
# 533144             RB  Jeremy McNichols          3.0
# 533162             TE       Ben Sinnott          2.0
#
# [535814 rows x 16 columns]

# %%
depth.to_csv('data/depth.csv')

# %%
rosters = nfl.import_weekly_rosters(range(2012,2024))
rosters
# Out:
#         season team position depth_chart_position jersey_number status  \
# 0         2012   SF        K                 None             2    ACT
# 1         2012   SF        K                 None             2    ACT
# 2         2012   SF        K                 None             2    ACT
# 3         2012   SF        K                 None             2    ACT
# 4         2012   SF        K                 None             2    ACT
# ...        ...  ...      ...                  ...           ...    ...
# 500244    2023  DEN       LB                   LB           NaN    DEV
# 500245    2023  DEN       LB                   LB           NaN    DEV
# 500246    2023  DEN       LB                   LB           NaN    DEV
# 500247    2023  DEN       LB                   LB           NaN    DEV
# 500248    2023  DEN       LB                   LB           NaN    DEV
#
#           player_name first_name last_name birth_date  height  weight college  \
# 0         David Akers      David     Akers 1974-12-09    70.0   200.0    None
# 1         David Akers      David     Akers 1974-12-09    70.0   200.0    None
# 2         David Akers      David     Akers 1974-12-09    70.0   200.0    None
# 3         David Akers      David     Akers 1974-12-09    70.0   200.0    None
# 4         David Akers      David     Akers 1974-12-09    70.0   200.0    None
# ...               ...        ...       ...        ...     ...     ...     ...
# 500244  Durell Nchami     Durell    Nchami        NaT     NaN   260.0    None
# 500245  Durell Nchami     Durell    Nchami        NaT     NaN   260.0    None
# 500246  Durell Nchami     Durell    Nchami        NaT     NaN   260.0    None
# 500247  Durell Nchami     Durell    Nchami        NaT     NaN   260.0    None
# 500248  Durell Nchami     Durell    Nchami        NaT     NaN   260.0    None
#
#          player_id espn_id  ... years_exp  \
# 0       00-0000108    None  ...      15.0
# 1       00-0000108    None  ...      15.0
# 2       00-0000108    None  ...      15.0
# 3       00-0000108    None  ...      15.0
# 4       00-0000108    None  ...      15.0
# ...            ...     ...  ...       ...
# 500244        None    None  ...       0.0
# 500245        None    None  ...       0.0
# 500246        None    None  ...       0.0
# 500247        None    None  ...       0.0
# 500248        None    None  ...       0.0
#
#                                              headshot_url ngs_position week  \
# 0       https://static.www.nfl.com/image/private/f_aut...         None   12
# 1       https://static.www.nfl.com/image/private/f_aut...         None   16
# 2       https://static.www.nfl.com/image/private/f_aut...         None    8
# 3       https://static.www.nfl.com/image/private/f_aut...         None    1
# 4       https://static.www.nfl.com/image/private/f_aut...         None   11
# ...                                                   ...          ...  ...
# 500244                                               None         None   18
# 500245                                               None         None   14
# 500246                                               None         None   15
# 500247                                               None         None   16
# 500248                                               None         None   17
#
#        game_type status_description_abbr football_name     esb_id gsis_it_id  \
# 0            REG                     A01         David  AKE551610       None
# 1            REG                     A01         David  AKE551610       None
# 2            REG                     A01         David  AKE551610       None
# 3            REG                     A01         David  AKE551610       None
# 4            REG                     A01         David  AKE551610       None
# ...          ...                     ...           ...        ...        ...
# 500244       REG                     P01        Durell  NCH415291      57034
# 500245       REG                     P01        Durell       None      57034
# 500246       REG                     P01        Durell  NCH415291      57034
# 500247       REG                     P01        Durell  NCH415291      57034
# 500248       REG                     P01        Durell  NCH415291      57034
#
#                                     smart_id  entry_year rookie_year  \
# 0       3200414b-4555-1610-e0e6-a72c82e419e7      1997.0      1997.0
# 1       3200414b-4555-1610-e0e6-a72c82e419e7      1997.0      1997.0
# 2       3200414b-4555-1610-e0e6-a72c82e419e7      1997.0      1997.0
# 3       3200414b-4555-1610-e0e6-a72c82e419e7      1997.0      1997.0
# 4       3200414b-4555-1610-e0e6-a72c82e419e7      1997.0      1997.0
# ...                                      ...         ...         ...
# 500244                                  None      2023.0      2023.0
# 500245                                  None      2023.0      2023.0
# 500246                                  None      2023.0      2023.0
# 500247                                  None      2023.0      2023.0
# 500248                                  None      2023.0      2023.0
#
#        draft_club draft_number     age
# 0            None         None  37.963
# 1            None         None  38.040
# 2            None         None  37.889
# 3            None         None  37.752
# 4            None         None  37.947
# ...           ...          ...     ...
# 500244       None          NaN     NaN
# 500245       None          NaN     NaN
# 500246       None          NaN     NaN
# 500247       None          NaN     NaN
# 500248       None          NaN     NaN
#
# [500249 rows x 37 columns]

# %%
ids = nfl.import_ids()

# %%
snaps = nfl.import_snap_counts(range(2012,2025))
team_map = {'OAK':'LV',
            'STL':'LA',
            'SD':'LAC'}
snaps['team'] = snaps['team'].apply(lambda x: team_map.get(x,x))

# %%
len(snaps)
# Out:
# 310635

# %%
#get receiver ids from pbp with name like 'J.Coker' to fill gaps
receivers = pbp[['posteam','season','receiver_player_id', 'receiver_player_name']].dropna().drop_duplicates().copy().rename(
    {'posteam':'team','defteam':'opponent','receiver_player_id':'player_id', 'receiver_player_name':'abbr_name'},axis=1)
receivers['last_name']= receivers['abbr_name'].apply(lambda x: x.split('.')[-1])
#get rosters to fill most of the gaps
rosters = rosters.rename({'player_name':'player'},axis=1)
rosters_ids = rosters.loc[~rosters.player_id.isna()][['player', 'player_id','team','week','season']]
clean_snaps = snaps.merge(ids[['gsis_id','pfr_id','name']], left_on=['pfr_player_id'], right_on=['pfr_id']).dropna()
missing = snaps.merge(ids[['gsis_id','pfr_id','name']],how='left', left_on=['pfr_player_id'], right_on=['pfr_id'])
missing = missing[missing.isna().any(axis=1)].drop(['gsis_id','pfr_id','name'], axis=1)
with_rosters = missing.merge(rosters_ids, how='left').drop_duplicates()
clean_from_rosters = with_rosters.dropna()
#fill remaining gaps with pbp receiver ids from above
still_missing = with_rosters.loc[with_rosters.player_id.isna()].copy().drop(['player_id'],axis=1)
still_missing['last_name'] = still_missing['player'].apply(lambda x: ' '.join(x.split(' ')[1:]))
from_receivers = still_missing.merge(receivers, on=['team','season', 'last_name'], how='left').drop('abbr_name',axis=1)
clean_from_receivers = from_receivers.dropna()
still_missing = from_receivers.loc[from_receivers.player_id.isna()].copy()

# %%
final = pd.concat((clean_snaps, clean_from_rosters.rename({'player_id':'gsis_id'},axis=1)))
final = pd.concat((final, clean_from_receivers.rename({'player_id':'gsis_id'},axis=1)))
final = final.drop(['last_name','pfr_id','name'],axis=1)
final
# Out:
#                game_id   pfr_game_id  season game_type  week  \
# 0       2012_01_ATL_KC  201209090kan    2012       REG     1
# 1       2012_01_ATL_KC  201209090kan    2012       REG     1
# 2       2012_01_ATL_KC  201209090kan    2012       REG     1
# 3       2012_01_ATL_KC  201209090kan    2012       REG     1
# 4       2012_01_ATL_KC  201209090kan    2012       REG     1
# ...                ...           ...     ...       ...   ...
# 22998  2024_11_MIN_TEN  202411170oti    2024       REG    11
# 23037   2024_11_SEA_SF  202411170sfo    2024       REG    11
# 23057  2024_11_WAS_PHI  202411140phi    2024       REG    11
# 23072  2024_11_WAS_PHI  202411140phi    2024       REG    11
# 23079  2024_12_PIT_CLE  202411210cle    2024       REG    12
#
#                  player pfr_player_id position team opponent  offense_snaps  \
# 0           Matt Cassel      CassMa00       QB   KC      ATL           69.0
# 1           Dwayne Bowe      BoweDw00       WR   KC      ATL           60.0
# 2      Dexter McCluster      McClDe00       WR   KC      ATL           57.0
# 3        Steve Breaston      BreaSt00       WR   KC      ATL           52.0
# 4           Tony Moeaki      MoeaTo00       TE   KC      ATL           45.0
# ...                 ...           ...      ...  ...      ...            ...
# 22998      Bryce Oliver      OlivBr02       WR  TEN      MIN            2.0
# 23037        Cody White      WhitCo05       WR  SEA       SF            4.0
# 23057    Ben VanSumeren      VanSBe00       LB  PHI      WAS            0.0
# 23072     Trenton Scott      ScotTr01        T  WAS      PHI            0.0
# 23079  Blake Whiteheart      WhitBl01       TE  CLE      PIT           10.0
#
#        offense_pct  defense_snaps  defense_pct  st_snaps  st_pct     gsis_id
# 0             1.00            0.0          0.0       0.0    0.00  00-0023662
# 1             0.87            0.0          0.0       0.0    0.00  00-0025410
# 2             0.83            0.0          0.0       0.0    0.00  00-0027651
# 3             0.75            0.0          0.0       0.0    0.00  00-0025529
# 4             0.65            0.0          0.0       0.0    0.00  00-0027695
# ...            ...            ...          ...       ...     ...         ...
# 22998         0.03            0.0          0.0      10.0    0.38  00-0039650
# 23037         0.07            0.0          0.0      14.0    0.67  00-0035891
# 23057         0.00            0.0          0.0      19.0    0.70  00-0038489
# 23072         0.00            0.0          0.0       2.0    0.07  00-0034571
# 23079         0.17            0.0          0.0       7.0    0.35  00-0038710
#
# [291315 rows x 17 columns]

# %%
final.to_csv('data/snap_counts.csv')

# %%
ids = nfl.import_ids()
ids.columns
# Out:
# Index(['cfbref_id', 'name', 'swish_id', 'gsis_id', 'college', 'cbs_id',
#        'merge_name', 'sportradar_id', 'team', 'draft_year', 'draft_pick',
#        'draft_round', 'pff_id', 'espn_id', 'rotoworld_id', 'mfl_id',
#        'draft_ovr', 'stats_global_id', 'sleeper_id', 'ktc_id',
#        'fantasy_data_id', 'twitter_username', 'position', 'stats_id',
#        'db_season', 'height', 'fleaflicker_id', 'pfr_id', 'weight', 'age',
#        'nfl_id', 'rotowire_id', 'birthdate', 'fantasypros_id', 'yahoo_id'],
#       dtype='object')
