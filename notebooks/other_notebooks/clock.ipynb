# %%
from utils.quack import Quack

# %%
pbp = Quack.query('select * from pbp where season = 2025')

# %%
pbp['game_id'].unique()
# Out:
# array(['2025_01_ARI_NO', '2025_01_BAL_BUF', '2025_01_CAR_JAX',
#        '2025_01_CIN_CLE', '2025_01_DAL_PHI', '2025_01_DET_GB',
#        '2025_01_HOU_LA', '2025_01_KC_LAC', '2025_01_LV_NE',
#        '2025_01_MIA_IND', '2025_01_MIN_CHI', '2025_01_NYG_WAS',
#        '2025_01_PIT_NYJ', '2025_01_SF_SEA', '2025_01_TB_ATL',
#        '2025_01_TEN_DEN', '2025_02_ATL_MIN', '2025_02_BUF_NYJ',
#        '2025_02_CAR_ARI', '2025_02_CHI_DET', '2025_02_CLE_BAL',
#        '2025_02_DEN_IND', '2025_02_JAX_CIN', '2025_02_LAC_LV',
#        '2025_02_LA_TEN', '2025_02_NE_MIA', '2025_02_NYG_DAL',
#        '2025_02_PHI_KC', '2025_02_SEA_PIT', '2025_02_SF_NO',
#        '2025_02_TB_HOU', '2025_02_WAS_GB', '2025_03_ARI_SF',
#        '2025_03_ATL_CAR', '2025_03_CIN_MIN', '2025_03_DAL_CHI',
#        '2025_03_DEN_LAC', '2025_03_DET_BAL', '2025_03_GB_CLE',
#        '2025_03_HOU_JAX', '2025_03_IND_TEN', '2025_03_KC_NYG',
#        '2025_03_LA_PHI', '2025_03_LV_WAS', '2025_03_MIA_BUF',
#        '2025_03_NO_SEA', '2025_03_NYJ_TB', '2025_03_PIT_NE',
#        '2025_04_BAL_KC', '2025_04_CAR_NE', '2025_04_CHI_LV',
#        '2025_04_CIN_DEN', '2025_04_CLE_DET', '2025_04_GB_DAL',
#        '2025_04_IND_LA', '2025_04_JAX_SF', '2025_04_LAC_NYG',
#        '2025_04_MIN_PIT', '2025_04_NO_BUF', '2025_04_NYJ_MIA',
#        '2025_04_PHI_TB', '2025_04_SEA_ARI', '2025_04_TEN_HOU',
#        '2025_04_WAS_ATL', '2025_05_DAL_NYJ', '2025_05_DEN_PHI',
#        '2025_05_DET_CIN', '2025_05_HOU_BAL', '2025_05_KC_JAX',
#        '2025_05_LV_IND', '2025_05_MIA_CAR', '2025_05_MIN_CLE',
#        '2025_05_NE_BUF', '2025_05_NYG_NO', '2025_05_SF_LA',
#        '2025_05_TB_SEA', '2025_05_TEN_ARI', '2025_05_WAS_LAC'],
#       dtype=object)

# %%
sm = pbp.loc[pbp.game_id == '2025_05_NE_BUF']
sm
# Out:
#        play_id         game_id old_game_id home_team away_team season_type  \
# 12414      1.0  2025_05_NE_BUF  2025100511       BUF        NE         REG
# 12415     39.0  2025_05_NE_BUF  2025100511       BUF        NE         REG
# 12416     65.0  2025_05_NE_BUF  2025100511       BUF        NE         REG
# 12417     90.0  2025_05_NE_BUF  2025100511       BUF        NE         REG
# 12418    112.0  2025_05_NE_BUF  2025100511       BUF        NE         REG
# ...        ...             ...         ...       ...       ...         ...
# 12581   4340.0  2025_05_NE_BUF  2025100511       BUF        NE         REG
# 12582   4367.0  2025_05_NE_BUF  2025100511       BUF        NE         REG
# 12583   4413.0  2025_05_NE_BUF  2025100511       BUF        NE         REG
# 12584   4401.0  2025_05_NE_BUF  2025100511       BUF        NE         REG
# 12585   4433.0  2025_05_NE_BUF  2025100511       BUF        NE         REG
#
#        week posteam posteam_type defteam  ... out_of_bounds  \
# 12414     5    None         None    None  ...           0.0
# 12415     5      NE         away     BUF  ...           0.0
# 12416     5      NE         away     BUF  ...           0.0
# 12417     5      NE         away     BUF  ...           0.0
# 12418     5      NE         away     BUF  ...           0.0
# ...     ...     ...          ...     ...  ...           ...
# 12581     5      NE         away     BUF  ...           0.0
# 12582     5     BUF         home      NE  ...           0.0
# 12583     5    None         None    None  ...           0.0
# 12584     5     BUF         home      NE  ...           0.0
# 12585     5     BUF         home      NE  ...           0.0
#
#        home_opening_kickoff    qb_epa  xyac_epa  xyac_mean_yardage  \
# 12414                   0.0 -0.000000       NaN                NaN
# 12415                   0.0  0.315104       NaN                NaN
# 12416                   0.0  1.040475  0.532724           4.207415
# 12417                   0.0 -0.877352       NaN                NaN
# 12418                   0.0 -0.162128  1.371828          11.028456
# ...                     ...       ...       ...                ...
# 12581                   0.0  1.310192       NaN                NaN
# 12582                   0.0 -0.045348       NaN                NaN
# 12583                   0.0  0.000000       NaN                NaN
# 12584                   0.0 -0.009662  0.080132           3.247417
# 12585                   0.0       NaN       NaN                NaN
#
#        xyac_median_yardage xyac_success   xyac_fd     xpass    pass_oe
# 12414                  NaN          NaN       NaN       NaN        NaN
# 12415                  NaN          NaN       NaN       NaN        NaN
# 12416                  2.0     0.772566  0.231193  0.438705  56.129506
# 12417                  NaN          NaN       NaN  0.436967 -43.696749
# 12418                 10.0     0.329233  0.156742  0.712862  28.713799
# ...                    ...          ...       ...       ...        ...
# 12581                  NaN          NaN       NaN       NaN        NaN
# 12582                  NaN          NaN       NaN       NaN        NaN
# 12583                  NaN          NaN       NaN       NaN        NaN
# 12584                  1.0     1.000000  0.998799  0.992693   0.730717
# 12585                  NaN          NaN       NaN       NaN        NaN
#
# [172 rows x 372 columns]

# %%
c = ['play_id','posteam','defteam','desc',
'quarter_seconds_remaining',
 'half_seconds_remaining',
 'game_seconds_remaining',
 'time',
 'timeout',
 'timeout_team',
 'start_time',
 'play_clock',
 'end_clock_time',
 'drive_time_of_possession',
 'drive_game_clock_start',
 'drive_game_clock_end',
 'drive']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 pd.set_option('display.max_colwidth', 100)
#       2 c = ['play_id','posteam','defteam','desc',
#       3 'quarter_seconds_remaining',
#       4  'half_seconds_remaining',
#    (...)
#      14  'drive_game_clock_end',
#      15  'drive']
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
pd.set_option('display.max_colwidth', 100)
sm.loc[sm.drive==1, c]
# Out:
#        play_id posteam defteam  \
# 12415     39.0      NE     BUF
# 12416     65.0      NE     BUF
# 12417     90.0      NE     BUF
# 12418    112.0      NE     BUF
# 12419    137.0      NE     BUF
# 12420    157.0      NE     BUF
#
#                                                                                                     desc  \
# 12415  15-M.Prater kicks 60 yards from BUF 35 to NE 5. 4-A.Gibson to NE 30 for 25 yards (28-S.Franklin).
# 12416      (14:54) 10-D.Maye pass short left to 8-S.Diggs to NE 45 for 15 yards (9-T.Rapp; 58-M.Milano).
# 12417                         (14:15) 38-R.Stevenson right tackle to NE 43 for -2 yards (50-G.Rousseau).
# 12418      (13:40) (Shotgun) 10-D.Maye pass short left to 4-A.Gibson to NE 48 for 5 yards (8-T.Bernard).
# 12419                          (12:59) (Shotgun) 10-D.Maye sacked at NE 46 for -2 yards (50-G.Rousseau).
# 12420      (12:26) 17-B.Baringer punts 40 yards to BUF 14, Center-47-J.Ashby, fair catch by 10-K.Shakir.
#
#        quarter_seconds_remaining  half_seconds_remaining  \
# 12415                      900.0                  1800.0
# 12416                      894.0                  1794.0
# 12417                      855.0                  1755.0
# 12418                      820.0                  1720.0
# 12419                      779.0                  1679.0
# 12420                      746.0                  1646.0
#
#        game_seconds_remaining   time  timeout timeout_team         start_time  \
# 12415                  3600.0  15:00      0.0         None  10/5/25, 20:23:06
# 12416                  3594.0  14:54      0.0         None  10/5/25, 20:23:06
# 12417                  3555.0  14:15      0.0         None  10/5/25, 20:23:06
# 12418                  3520.0  13:40      0.0         None  10/5/25, 20:23:06
# 12419                  3479.0  12:59      0.0         None  10/5/25, 20:23:06
# 12420                  3446.0  12:26      0.0         None  10/5/25, 20:23:06
#
#       play_clock            end_clock_time drive_time_of_possession  \
# 12415          0  2025-10-06T00:23:14.013Z                     2:42
# 12416          0  2025-10-06T00:23:51.357Z                     2:42
# 12417          0  2025-10-06T00:24:26.247Z                     2:42
# 12418          0  2025-10-06T00:25:03.333Z                     2:42
# 12419          0  2025-10-06T00:25:43.190Z                     2:42
# 12420          0  2025-10-06T00:26:18.227Z                     2:42
#
#       drive_game_clock_start drive_game_clock_end  drive
# 12415                  15:00                12:18    1.0
# 12416                  15:00                12:18    1.0
# 12417                  15:00                12:18    1.0
# 12418                  15:00                12:18    1.0
# 12419                  15:00                12:18    1.0
# 12420                  15:00                12:18    1.0
