# %%
import pandas as pd

# %%
pbp = pd.read_csv('../reference_data/NFL/pbp/play_by_play_2024.csv')
pbp
# Out:
# C:\Users\Sharedw\AppData\Local\Temp\ipykernel_25356\4166099489.py:1: DtypeWarning: Columns (45,49,179,180,182,183,189,190,195,196,197,198,203,204,205,206,213,214,222,224,226,233,234,235,236,237,238,266,267,268,269,272,273,274,278,283,284) have mixed types. Specify dtype option on import or set low_memory=False.
#   pbp = pd.read_csv('../reference_data/NFL/pbp/play_by_play_2024.csv')
#        play_id          game_id  old_game_id home_team away_team season_type  \
# 0            1  2024_01_ARI_BUF   2024090801       BUF       ARI         REG
# 1           40  2024_01_ARI_BUF   2024090801       BUF       ARI         REG
# 2           61  2024_01_ARI_BUF   2024090801       BUF       ARI         REG
# 3           83  2024_01_ARI_BUF   2024090801       BUF       ARI         REG
# 4          108  2024_01_ARI_BUF   2024090801       BUF       ARI         REG
# ...        ...              ...          ...       ...       ...         ...
# ...

# %%
list(pbp.columns)
# Out:
# ['play_id',
#  'game_id',
#  'old_game_id',
#  'home_team',
#  'away_team',
#  'season_type',
#  'week',
#  'posteam',
#  'posteam_type',
#  'defteam',
#  'side_of_field',
#  'yardline_100',
#  'game_date',
#  'quarter_seconds_remaining',
#  'half_seconds_remaining',
#  'game_seconds_remaining',
#  'game_half',
#  'quarter_end',
#  'drive',
#  'sp',
#  'qtr',
#  'down',
#  'goal_to_go',
#  'time',
#  'yrdln',
#  'ydstogo',
#  'ydsnet',
#  'desc',
#  'play_type',
#  'yards_gained',
#  'shotgun',
#  'no_huddle',
#  'qb_dropback',
#  'qb_kneel',
#  'qb_spike',
#  'qb_scramble',
#  'pass_length',
#  'pass_location',
#  'air_yards',
#  'yards_after_catch',
#  'run_location',
#  'run_gap',
#  'field_goal_result',
#  'kick_distance',
#  'extra_point_result',
#  'two_point_conv_result',
#  'home_timeouts_remaining',
#  'away_timeouts_remaining',
#  'timeout',
#  'timeout_team',
#  'td_team',
#  'td_player_name',
#  'td_player_id',
#  'posteam_timeouts_remaining',
# ...

# %%
pbp.iloc[0:2].dropna(axis=1)
# Out:
#    play_id          game_id  old_game_id home_team away_team season_type  \
# 0        1  2024_01_ARI_BUF   2024090801       BUF       ARI         REG
# 1       40  2024_01_ARI_BUF   2024090801       BUF       ARI         REG
#
#    week   game_date  quarter_seconds_remaining  half_seconds_remaining  ...  \
# 0     1  2024-09-08                      900.0                  1800.0  ...
# 1     1  2024-09-08                      900.0                  1800.0  ...
#
#     game_stadium aborted_play  success  pass  rush  special play  \
# 0  New Era Field            0      0.0     0     0        0    0
# 1  New Era Field            0      1.0     0     0        1    0
#
#   out_of_bounds  home_opening_kickoff    qb_epa
# 0             0                     0  0.000000
# 1             0                     0  0.257819
#
# [2 rows x 117 columns]

# %%
pbp['play_type'].value_counts()
# Out:
# play_type
# pass           7372
# run            5658
# no_play        1862
# kickoff        1096
# punt            829
# extra_point     469
# field_goal      451
# qb_kneel        171
# qb_spike         25
# Name: count, dtype: int64
