# %%
import pandas as pd
from utils.betting import (
	get_pp_close,
)
pd.set_option("display.precision", 3)

# %%
pp = get_pp_close()
pp = pp.loc[pp.league_name == 'NFL'].copy(deep=True).reset_index(drop=True)

# %%
games = pd.DataFrame()
for year in range(2000,2025):
    temp = pd.read_csv(f'../reference_data/NFL/game_logs_{year}.csv',index_col=0,parse_dates=['date'])
    games = pd.concat((games, temp))
ref2pp = {
    'GNB':'GB',
    'JAX':'JAC',
    'KAN':'KC',
    'LVR':'LV',
    'NOR':'NO',
    'NWE':'NE',
    'SFO':'SF',     
    'TAM':'TB',
}

games['team'] = games['team'].apply(lambda x: ref2pp.get(x,x))
players = pd.read_csv('../reference_data/NFL/player_info.csv',index_col=0)

games['Rush+Rec TDs'] = games['Rec TDs'] + games['Rush TDs']
games['Completion Percentage'] = 100 * (games['Pass Completions'] / games['Pass Attempts'])
games['Pass+Rush Yds'] = games['Pass Yards'] + games['Rush Yards']
games['Rush+Rec Yds'] = games['Receiving Yards'] + games['Rush Yards']
games[['XPM','FG']] = games[['XPM','FG']].astype(float)
games['Kicking Points'] = games['XPM'] + (3 * games['FG'])
games['Fantasy Score'] = ((games['Pass Yards'] * 0.04) + (games['Pass TDs'] * 4) + (2 * -games['INT']) + (games['Rush Yards'] * 0.1) + (games['Receiving Yards'] * 0.1) + #missing 2 pt conv
                    (games['Receptions']) + (-games['Fumbles Lost']) + (games['Rush+Rec TDs'] * 6))

# %%
players.loc[(players.PosRank < 90) & (players.GS > 1)]
# Out:
#         Rk            player team FantPos  age   G    GS    Cmp    Att  \
# 0        1    Marshall Faulk  STL      RB   27  14  14.0    0.0    0.0
# 1        2    Edgerrin James  IND      RB   22  16  16.0    0.0    0.0
# 2        3       Jeff Garcia  SFO      QB   30  16  16.0  355.0  561.0
# 3        4  Daunte Culpepper  MIN      QB   23  16  16.0  297.0  474.0
# 4        5      Eddie George  TEN      RB   27  16  16.0    0.0    0.0
# ...    ...               ...  ...     ...  ...  ..   ...    ...    ...
# 15449  363     MyCole Pruitt  PIT      TE   32   2   2.0    0.0    0.0
# 15452  366     Durham Smythe  MIA      TE   29   4   2.0    0.0    0.0
# 15455  368     Adam Trautman  DEN      TE   27   4   4.0    0.0    0.0
# 15483  396    Gerald Everett  CHI      TE   30   4   3.0    0.0    0.0
# 15500  413    Connor Heyward  PIT      TE   25   4   2.0    0.0    0.0
#
#           Yds  ...   FDPt    VBD  PosRank  OvRank  year  round   pick  Pos  \
# 0         0.0  ...  419.4  228.0        1     1.0  2000    1.0    2.0   RB
# 1         0.0  ...  363.8  181.0        2     2.0  2000    1.0    4.0   RB
# 2      4278.0  ...  350.5  149.0        1     3.0  2000    NaN    NaN  NaN
# 3      3937.0  ...  354.5  147.0        2     4.0  2000    1.0   11.0   QB
# 4         0.0  ...  309.2  133.0        3     5.0  2000    1.0   14.0   RB
# ...       ...  ...    ...    ...      ...     ...   ...    ...    ...  ...
# 15449     0.0  ...    1.4    NaN       71     NaN  2024    5.0  143.0   TE
# 15452     0.0  ...    2.1    NaN       70     NaN  2024    4.0  123.0   TE
# 15455     0.0  ...    1.8    NaN       68     NaN  2024    3.0  105.0   TE
# 15483     0.0  ...    1.5    NaN       85     NaN  2024    2.0   44.0   TE
# 15500     0.0  ...    0.7    NaN       80     NaN  2024    6.0  208.0   TE
#
#                  college  draft_year
# 0          San Diego St.      1994.0
# 1             Miami (FL)      1999.0
# 2                    NaN      2000.0
# 3        Central Florida      1999.0
# 4               Ohio St.      1996.0
# ...                  ...         ...
# 15449  Southern Illinois      2015.0
# 15452         Notre Dame      2018.0
# 15455             Dayton      2020.0
# 15483      South Alabama      2017.0
# 15500       Michigan St.      2022.0
#
# [7213 rows x 39 columns]

# %%
players['FantPos'].value_counts()
k_players = games.loc[games.pos=='K']

# %%
top_players = players.loc[(players.PosRank < 90) & (players.GS > 1)]
games = games.merge(top_players[['player','FantPos']]).drop_duplicates()

# %%
games = pd.concat((games,k_players))

# %%
games['FantPos']= games['FantPos'].fillna(games['pos'])

# %%
games.columns
# Out:
# Index(['player', 'team', 'Pass Completions', 'Pass Attempts', 'Pass Yards',
#        'Pass TDs', 'INT', 'Sacks', 'Yards Sacked', 'Longest Pass',
#        'Passing Rate', 'Rush Attempts', 'Rush Yards', 'Rush TDs',
#        'Longest Rush', 'Rec Targets', 'Receptions', 'Receiving Yards',
#        'Rec TDs', 'Longest Reception', 'Fumbles', 'Fumbles Lost', 'XPM', 'XPA',
#        'FG', 'FGA', 'date', 'opp', 'home', 'roof', 'surface', 'weather',
#        'game_line', 'favored', 'total', 'Kicking Points', 'season', 'pos',
#        'snaps', 'pct', 'Rush+Rec TDs', 'Completion Percentage',
#        'Pass+Rush Yds', 'Rush+Rec Yds', 'Fantasy Score', 'FantPos'],
#       dtype='object')

# %%
common_cols = [ 'team', 'opp', 'home', 'roof', 'surface', 'weather', 'game_line', 'favored', 'total',
       'season',  'date']
qb_cols =     ['player', 'Pass Completions', 'Pass Attempts', 'Pass Yards',
       'Pass TDs', 'INT', 'Sacks', 'Yards Sacked', 'Longest Pass',
       'Passing Rate',  'snaps', 'pct', 'pos', 'FantPos',]
wr_cols =     ['player', 'Rec Targets', 'Receptions', 'Receiving Yards', 'Rush+Rec Yds', 
       'Rec TDs','Rush+Rec TDs', 'Longest Reception', 'Fantasy Score',  'snaps', 'pct', 'pos', 'FantPos']
rb_cols =     ['player', 'Rush Attempts', 'Rush Yards', 'Rush TDs', 'Rush+Rec Yds', 
       'Longest Rush', 'Rec Targets', 'Receptions', 'Receiving Yards',
       'Rec TDs','Rush+Rec TDs', 'Longest Reception', 'Fumbles', 'Fumbles Lost', 'Fantasy Score', 'snaps', 'pct',
        'pos', 'FantPos']

# %%
common_cols = [ 'team', 'opp', 'home', 'roof', 'surface', 'weather', 'game_line', 'favored', 'total',
       'season',  'date']
qb_cols =     ['player', 'Pass Completions', 'Pass Attempts', 'Pass Yards',
       'Pass TDs', 'INT', 'Sacks', 'Yards Sacked', 'Longest Pass',
       'Passing Rate',  'snaps', 'pct', 'pos', 'FantPos',]
wr_cols =     ['player', 'Rec Targets', 'Receptions', 'Receiving Yards', 'Rush+Rec Yds', 
       'Rec TDs','Rush+Rec TDs', 'Longest Reception', 'Fantasy Score',  'snaps', 'pct', 'pos', 'FantPos']
rb_cols =     ['player', 'Rush Attempts', 'Rush Yards', 'Rush TDs', 'Rush+Rec Yds', 
       'Longest Rush', 'Rec Targets', 'Receptions', 'Receiving Yards',
       'Rec TDs','Rush+Rec TDs', 'Longest Reception', 'Fumbles', 'Fumbles Lost', 'Fantasy Score', 'snaps', 'pct',
        'pos', 'FantPos']

k_cols = ['player', 'XPM','Kicking Points', 'Fantasy Score', 'FG','snaps', 'pct', 'pos', 'FantPos']

small = games.loc[games['date'] > '2014-09-01']

qb = small.loc[small.FantPos=='QB'][
    qb_cols + common_cols
]
wr = small.loc[small.FantPos=='WR'][
    wr_cols + common_cols
]
rb = small.loc[small.FantPos=='RB'][
    rb_cols + common_cols
]
te = small.loc[small.FantPos=='TE'][
    wr_cols + common_cols
]
k = small.loc[small.FantPos=='K'][
    k_cols + common_cols
]

# %%
context_cols = ['player', 'snaps','pct', 'FantPos','pos'] + common_cols

pairs = pd.DataFrame()
for pair in [(qb,wr), (qb,rb), (qb,te), (wr,wr),(wr,rb),(wr,te),(rb,rb),(rb,te), (qb,k), (wr,k), (rb,k)]:
    temp1 = pair[0].melt(id_vars=context_cols)
    temp2 = pair[1].melt(id_vars=context_cols)
    temp3 = temp1.merge(temp2,on=common_cols)
    pairs=pd.concat((pairs, temp3))
pairs = pairs.loc[pairs.player_x!=pairs.player_y].drop_duplicates()

# %%
print(len(pairs))
pairs.head(5)
# Out:
# 22355141
#          player_x  snaps_x pct_x FantPos_x pos_x team  opp  home      roof  \
# 0  Peyton Manning     75.0  100%        QB    QB  DEN  IND     1  outdoors
# 1  Peyton Manning     75.0  100%        QB    QB  DEN  IND     1  outdoors
# 2  Peyton Manning     75.0  100%        QB    QB  DEN  IND     1  outdoors
# 3  Peyton Manning     75.0  100%        QB    QB  DEN  IND     1  outdoors
# 4  Peyton Manning     75.0  100%        QB    QB  DEN  IND     1  outdoors
#
#   surface  ...       date        variable_x value_x          player_y  \
# 0   grass  ... 2014-09-07  Pass Completions    22.0    Andre Caldwell
# 1   grass  ... 2014-09-07  Pass Completions    22.0  Demaryius Thomas
# 2   grass  ... 2014-09-07  Pass Completions    22.0  Emmanuel Sanders
# 3   grass  ... 2014-09-07  Pass Completions    22.0    Andre Caldwell
# 4   grass  ... 2014-09-07  Pass Completions    22.0  Demaryius Thomas
#
#    snaps_y pct_y FantPos_y  pos_y   variable_y  value_y
# 0     41.0   55%        WR     WR  Rec Targets      5.0
# 1     67.0   89%        WR     WR  Rec Targets     11.0
# 2     70.0   93%        WR     WR  Rec Targets      9.0
# 3     41.0   55%        WR     WR   Receptions      2.0
# 4     67.0   89%        WR     WR   Receptions      4.0
#
# [5 rows x 25 columns]

# %%
small = pairs
small
#16263501 
#8639003  
#8639003
#2401432
# Out:
#               player_x  snaps_x pct_x FantPos_x pos_x team  opp  home  \
# 0       Peyton Manning     75.0  100%        QB    QB  DEN  IND     1
# 1       Peyton Manning     75.0  100%        QB    QB  DEN  IND     1
# 2       Peyton Manning     75.0  100%        QB    QB  DEN  IND     1
# 3       Peyton Manning     75.0  100%        QB    QB  DEN  IND     1
# 4       Peyton Manning     75.0  100%        QB    QB  DEN  IND     1
# ...                ...      ...   ...       ...   ...  ...  ...   ...
# 704083   De'Von Achane     44.0   73%        RB    RB  MIA  TEN     1
# 704084   De'Von Achane     44.0   73%        RB    RB  MIA  TEN     1
# 704085   De'Von Achane     44.0   73%        RB    RB  MIA  TEN     1
# 704086   De'Von Achane     44.0   73%        RB    RB  MIA  TEN     1
# 704087   De'Von Achane     44.0   73%        RB    RB  MIA  TEN     1
#
#             roof surface  ...       date        variable_x value_x  \
# 0       outdoors   grass  ... 2014-09-07  Pass Completions    22.0
# 1       outdoors   grass  ... 2014-09-07  Pass Completions    22.0
# 2       outdoors   grass  ... 2014-09-07  Pass Completions    22.0
# 3       outdoors   grass  ... 2014-09-07  Pass Completions    22.0
# 4       outdoors   grass  ... 2014-09-07  Pass Completions    22.0
# ...          ...     ...  ...        ...               ...     ...
# 704083  outdoors   grass  ... 2024-09-30      Fumbles Lost     0.0
# 704084  outdoors   grass  ... 2024-09-30     Fantasy Score     5.9
# 704085  outdoors   grass  ... 2024-09-30     Fantasy Score     5.9
# 704086  outdoors   grass  ... 2024-09-30     Fantasy Score     5.9
# 704087  outdoors   grass  ... 2024-09-30     Fantasy Score     5.9
#
#                 player_y  snaps_y pct_y FantPos_y  pos_y      variable_y  \
# 0         Andre Caldwell     41.0   55%        WR     WR     Rec Targets
# 1       Demaryius Thomas     67.0   89%        WR     WR     Rec Targets
# 2       Emmanuel Sanders     70.0   93%        WR     WR     Rec Targets
# 3         Andre Caldwell     41.0   55%        WR     WR      Receptions
# 4       Demaryius Thomas     67.0   89%        WR     WR      Receptions
# ...                  ...      ...   ...       ...    ...             ...
# 704083     Jason Sanders      0.0    0%         K      K              FG
# 704084     Jason Sanders      0.0    0%         K      K             XPM
# 704085     Jason Sanders      0.0    0%         K      K  Kicking Points
# 704086     Jason Sanders      0.0    0%         K      K   Fantasy Score
# 704087     Jason Sanders      0.0    0%         K      K              FG
#
#         value_y
# 0           5.0
# 1          11.0
# 2           9.0
# 3           2.0
# 4           4.0
# ...         ...
# 704083      2.0
# 704084      NaN
# 704085      NaN
# 704086      NaN
# 704087      2.0
#
# [22355141 rows x 25 columns]

# %%
pos_corr= small.groupby(['FantPos_x','FantPos_y','variable_x','variable_y'])[['value_x','value_y']].corr()
pos_corr = pos_corr.loc[pos_corr.value_x != 1].reset_index().drop(['value_y' ,'level_4'],axis=1)
pos_corr.sort_values(by='value_x')
# Out:
#     FantPos_x FantPos_y     variable_x     variable_y  value_x
# 497        RB        RB  Rush Attempts  Rush Attempts   -0.310
# 31         QB         K          Sacks            XPM   -0.268
# 35         QB         K   Yards Sacked            XPM   -0.252
# 323        RB         K   Longest Rush  Fantasy Score   -0.242
# 525        RB        RB     Rush Yards  Rush Attempts   -0.240
# ..        ...       ...            ...            ...      ...
# 272        QB        WR       Pass TDs   Rush+Rec TDs    0.304
# 268        QB        WR       Pass TDs        Rec TDs    0.313
# 21         QB         K     Pass Yards  Fantasy Score    0.344
# 19         QB         K       Pass TDs            XPM    0.410
# 27         QB         K   Passing Rate            XPM    0.471
#
# [942 rows x 5 columns]

# %%
corr = small.groupby(['player_x','player_y', 'FantPos_x','FantPos_y','variable_x','variable_y'])[['value_x','value_y']].corr()
corr
# Out:
#                                                                                            value_x  \
# player_x       player_y       FantPos_x FantPos_y variable_x    variable_y
# A.J. Brown     Adam Humphries WR        WR        Fantasy Score Fantasy Score     value_x    1.000
#                                                                                   value_y   -0.195
#                                                                 Longest Reception value_x    1.000
#                                                                                   value_y   -0.085
#                                                                 Rec TDs           value_x    1.000
# ...                                                                                            ...
# Zonovan Knight Tyler Conklin  RB        TE        Rush+Rec Yds  Receptions        value_y   -0.003
#                                                                 Rush+Rec TDs      value_x    1.000
#                                                                                   value_y      NaN
#                                                                 Rush+Rec Yds      value_x    1.000
#                                                                                   value_y    0.012
#
#                                                                                            value_y
# player_x       player_y       FantPos_x FantPos_y variable_x    variable_y
# A.J. Brown     Adam Humphries WR        WR        Fantasy Score Fantasy Score     value_x   -0.195
#                                                                                   value_y    1.000
#                                                                 Longest Reception value_x   -0.085
#                                                                                   value_y    1.000
#                                                                 Rec TDs           value_x   -0.044
# ...                                                                                            ...
# Zonovan Knight Tyler Conklin  RB        TE        Rush+Rec Yds  Receptions        value_y    1.000
#                                                                 Rush+Rec TDs      value_x      NaN
#                                                                                   value_y      NaN
#                                                                 Rush+Rec Yds      value_x    0.012
#                                                                                   value_y    1.000
#
# [4261860 rows x 2 columns]

# %%
gp = small.groupby(['player_x','player_y','FantPos_x','FantPos_y','team', 'variable_x','variable_y'])['date'].count().reset_index()
gp.columns = ['player_x','player_y', 'FantPos_x','FantPos_y','team','variable_x','variable_y', 'gp' ]
gp = gp[['player_x','player_y','gp']].drop_duplicates()
gp.sort_values(by='gp')
# Out:
#                     player_x         player_y   gp
# 1496056        Melvin Gordon     Kenyan Drake    1
# 578464   Darrius Heyward-Bey         Ben Tate    1
# 1754450        Robert Foster  Jeremy Sprinkle    1
# 1600958           Nick Foles    Albert Wilson    1
# 1874032         Scott Miller     Ryan Griffin    1
# ...                      ...              ...  ...
# 1650496      Patrick Mahomes  Harrison Butker  114
# 1652602      Patrick Mahomes     Travis Kelce  116
# 19706          Aaron Rodgers    Davante Adams  117
# 584400         Davante Adams     Mason Crosby  123
# 21254          Aaron Rodgers     Mason Crosby  146
#
# [23363 rows x 3 columns]

# %%
corr = corr.reset_index()
corr2 = corr.loc[corr.value_x != 1]
corr2 = corr2.merge(gp)
corr2.loc[corr2.gp > 5].sort_values(by='value_x')
# Out:
#                  player_x        player_y FantPos_x FantPos_y  \
# 1854168      Mike Glennon     Graham Gano        QB         K
# 2256285      Shane Vereen  Brandon Bolden        RB        RB
# 2540959       Victor Cruz  Andre Williams        WR        RB
# 755326     DeMarco Murray  Anthony Fasano        RB        TE
# 210637   Benny Cunningham    Adam Shaheen        RB        TE
# ...                   ...             ...       ...       ...
# 2607746    Zonovan Knight   Tyler Conklin        RB        TE
# 2607750    Zonovan Knight   Tyler Conklin        RB        TE
# 2607754    Zonovan Knight   Tyler Conklin        RB        TE
# 2607758    Zonovan Knight   Tyler Conklin        RB        TE
# 2607762    Zonovan Knight   Tyler Conklin        RB        TE
#
#                variable_x         variable_y  level_6  value_x  value_y  gp
# 1854168  Pass Completions                XPM  value_y     -1.0      1.0   6
# 2256285        Receptions  Longest Reception  value_y     -1.0      1.0  10
# 2540959     Fantasy Score  Longest Reception  value_y     -1.0      1.0   6
# 755326            Fumbles         Receptions  value_y     -1.0      1.0   9
# 210637      Rush Attempts       Rush+Rec TDs  value_y     -1.0      1.0   8
# ...                   ...                ...      ...      ...      ...  ..
# 2607746        Rush Yards       Rush+Rec TDs  value_y      NaN      NaN   7
# 2607750      Rush+Rec TDs            Rec TDs  value_y      NaN      NaN   7
# 2607754      Rush+Rec TDs       Rush+Rec TDs  value_y      NaN      NaN   7
# 2607758      Rush+Rec Yds            Rec TDs  value_y      NaN      NaN   7
# 2607762      Rush+Rec Yds       Rush+Rec TDs  value_y      NaN      NaN   7
#
# [1289886 rows x 10 columns]

# %%
corr2.columns
# Out:
# Index(['player_x', 'player_y', 'FantPos_x', 'FantPos_y', 'variable_x',
#        'variable_y', 'level_6', 'value_x', 'value_y', 'gp'],
#       dtype='object')

# %%
out = corr2.merge(pos_corr[['FantPos_x', 'FantPos_y', 'variable_x',
       'variable_y', 'value_x']], on=['FantPos_x', 'FantPos_y', 'variable_x',
       'variable_y'], suffixes=['','_pos']).drop(['level_6','value_y'],axis=1)
out
# Out:
#                player_x        player_y FantPos_x FantPos_y     variable_x  \
# 0            A.J. Brown  Adam Humphries        WR        WR  Fantasy Score
# 1            A.J. Brown  Chester Rogers        WR        WR  Fantasy Score
# 2            A.J. Brown     Corey Davis        WR        WR  Fantasy Score
# 3            A.J. Brown   DeVonta Smith        WR        WR  Fantasy Score
# 4            A.J. Brown  Delanie Walker        WR        WR  Fantasy Score
# ...                 ...             ...       ...       ...            ...
# 2607759  Zonovan Knight    Brock Wright        RB        TE   Rush+Rec Yds
# 2607760  Zonovan Knight     C.J. Uzomah        RB        TE   Rush+Rec Yds
# 2607761  Zonovan Knight  Jeremy Ruckert        RB        TE   Rush+Rec Yds
# 2607762  Zonovan Knight  Jeremy Ruckert        RB        TE   Rush+Rec Yds
# 2607763  Zonovan Knight   Tyler Conklin        RB        TE   Rush+Rec Yds
#
#             variable_y  value_x  gp  value_x_pos
# 0        Fantasy Score   -0.195  18       -0.049
# 1        Fantasy Score   -0.451  13       -0.049
# 2        Fantasy Score    0.057  31       -0.049
# 3        Fantasy Score   -0.028  38       -0.049
# 4        Fantasy Score   -0.162   6       -0.049
# ...                ...      ...  ..          ...
# 2607759   Rush+Rec Yds      NaN   1       -0.025
# 2607760   Rush+Rec Yds   -0.435   6       -0.025
# 2607761   Rush+Rec Yds      NaN   1       -0.025
# 2607762   Rush+Rec Yds      NaN   1       -0.025
# 2607763   Rush+Rec Yds    0.012   7       -0.025
#
# [2607764 rows x 9 columns]

# %%
out['C'] = ((20 * out['value_x_pos']) + (out['gp'] * out['value_x'])) / (20 + out['gp'])
out
# Out:
#                player_x        player_y FantPos_x FantPos_y     variable_x  \
# 0            A.J. Brown  Adam Humphries        WR        WR  Fantasy Score
# 1            A.J. Brown  Chester Rogers        WR        WR  Fantasy Score
# 2            A.J. Brown     Corey Davis        WR        WR  Fantasy Score
# 3            A.J. Brown   DeVonta Smith        WR        WR  Fantasy Score
# 4            A.J. Brown  Delanie Walker        WR        WR  Fantasy Score
# ...                 ...             ...       ...       ...            ...
# 2607759  Zonovan Knight    Brock Wright        RB        TE   Rush+Rec Yds
# 2607760  Zonovan Knight     C.J. Uzomah        RB        TE   Rush+Rec Yds
# 2607761  Zonovan Knight  Jeremy Ruckert        RB        TE   Rush+Rec Yds
# 2607762  Zonovan Knight  Jeremy Ruckert        RB        TE   Rush+Rec Yds
# 2607763  Zonovan Knight   Tyler Conklin        RB        TE   Rush+Rec Yds
#
#             variable_y  value_x  gp  value_x_pos      C
# 0        Fantasy Score   -0.195  18       -0.049 -0.118
# 1        Fantasy Score   -0.451  13       -0.049 -0.207
# 2        Fantasy Score    0.057  31       -0.049  0.015
# 3        Fantasy Score   -0.028  38       -0.049 -0.035
# 4        Fantasy Score   -0.162   6       -0.049 -0.075
# ...                ...      ...  ..          ...    ...
# 2607759   Rush+Rec Yds      NaN   1       -0.025    NaN
# 2607760   Rush+Rec Yds   -0.435   6       -0.025 -0.120
# 2607761   Rush+Rec Yds      NaN   1       -0.025    NaN
# 2607762   Rush+Rec Yds      NaN   1       -0.025    NaN
# 2607763   Rush+Rec Yds    0.012   7       -0.025 -0.015
#
# [2607764 rows x 10 columns]

# %%
out.columns = ['player_1', 'player_2', 'FantPos_1', 'FantPos_2', 'stat_1',
       'stat_2', 'corr', 'gp', 'pos_corr', 'w_corr']

# %%
out
# Out:
#                player_1        player_2 FantPos_1 FantPos_2         stat_1  \
# 0            A.J. Brown  Adam Humphries        WR        WR  Fantasy Score
# 1            A.J. Brown  Chester Rogers        WR        WR  Fantasy Score
# 2            A.J. Brown     Corey Davis        WR        WR  Fantasy Score
# 3            A.J. Brown   DeVonta Smith        WR        WR  Fantasy Score
# 4            A.J. Brown  Delanie Walker        WR        WR  Fantasy Score
# ...                 ...             ...       ...       ...            ...
# 2607759  Zonovan Knight    Brock Wright        RB        TE   Rush+Rec Yds
# 2607760  Zonovan Knight     C.J. Uzomah        RB        TE   Rush+Rec Yds
# 2607761  Zonovan Knight  Jeremy Ruckert        RB        TE   Rush+Rec Yds
# 2607762  Zonovan Knight  Jeremy Ruckert        RB        TE   Rush+Rec Yds
# 2607763  Zonovan Knight   Tyler Conklin        RB        TE   Rush+Rec Yds
#
#                 stat_2   corr  gp  pos_corr  w_corr
# 0        Fantasy Score -0.195  18    -0.049  -0.118
# 1        Fantasy Score -0.451  13    -0.049  -0.207
# 2        Fantasy Score  0.057  31    -0.049   0.015
# 3        Fantasy Score -0.028  38    -0.049  -0.035
# 4        Fantasy Score -0.162   6    -0.049  -0.075
# ...                ...    ...  ..       ...     ...
# 2607759   Rush+Rec Yds    NaN   1    -0.025     NaN
# 2607760   Rush+Rec Yds -0.435   6    -0.025  -0.120
# 2607761   Rush+Rec Yds    NaN   1    -0.025     NaN
# 2607762   Rush+Rec Yds    NaN   1    -0.025     NaN
# 2607763   Rush+Rec Yds  0.012   7    -0.025  -0.015
#
# [2607764 rows x 10 columns]

# %%
out.sort_values(by='w_corr').dropna().to_csv('../reference_data/NFL/player_corr.csv')

# %%
out.loc[(out.player_1 =='David Montgomery') & (out.player_2=='Jahmyr Gibbs')].sort_values(by='w_corr').dropna().head(15)
# Out:
#                  player_1      player_2 FantPos_1 FantPos_2         stat_1  \
# 2050810  David Montgomery  Jahmyr Gibbs        RB        RB       Rush TDs
# 2125184  David Montgomery  Jahmyr Gibbs        RB        RB   Rush+Rec TDs
# 2026727  David Montgomery  Jahmyr Gibbs        RB        RB  Rush Attempts
# 2005271  David Montgomery  Jahmyr Gibbs        RB        RB  Rush Attempts
# 2113845  David Montgomery  Jahmyr Gibbs        RB        RB   Rush+Rec TDs
# 2038806  David Montgomery  Jahmyr Gibbs        RB        RB       Rush TDs
# 2029103  David Montgomery  Jahmyr Gibbs        RB        RB  Rush Attempts
# 2147855  David Montgomery  Jahmyr Gibbs        RB        RB   Rush+Rec TDs
# 2074811  David Montgomery  Jahmyr Gibbs        RB        RB       Rush TDs
# 1672158  David Montgomery  Jahmyr Gibbs        RB        RB  Fantasy Score
# 2036259  David Montgomery  Jahmyr Gibbs        RB        RB  Rush Attempts
# 1731150  David Montgomery  Jahmyr Gibbs        RB        RB        Fumbles
# 1779245  David Montgomery  Jahmyr Gibbs        RB        RB   Fumbles Lost
# 2077809  David Montgomery  Jahmyr Gibbs        RB        RB       Rush TDs
# 2150690  David Montgomery  Jahmyr Gibbs        RB        RB   Rush+Rec TDs
#
#                 stat_2   corr  gp  pos_corr  w_corr
# 2050810   Longest Rush -0.564  20    -0.026  -0.295
# 2125184   Longest Rush -0.564  20    -0.025  -0.295
# 2026727  Rush Attempts -0.215  20    -0.310  -0.262
# 2005271  Fantasy Score -0.304  20    -0.210  -0.257
# 2113845  Fantasy Score -0.424  20    -0.088  -0.256
# 2038806  Fantasy Score -0.424  20    -0.085  -0.254
# 2029103       Rush TDs -0.387  20    -0.116  -0.251
# 2147855   Rush+Rec TDs -0.423  20    -0.064  -0.244
# 2074811   Rush+Rec TDs -0.423  20    -0.062  -0.242
# 1672158   Longest Rush -0.387  20    -0.093  -0.240
# 2036259   Rush+Rec Yds -0.229  20    -0.240  -0.235
# 1731150     Rush Yards -0.409  20    -0.046  -0.228
# 1779245     Rush Yards -0.409  20    -0.045  -0.227
# 2077809   Rush+Rec Yds -0.358  20    -0.075  -0.217
# 2150690   Rush+Rec Yds -0.358  20    -0.073  -0.216

# %%
pd.set_option('display.float_format', '{:.3f}'.format)

# %%
pos_corr.loc[pos_corr.variable_x == "INT"].sort_values(by='value_x',ascending=False).head(40)
# Out:
#     FantPos_x FantPos_y variable_x         variable_y  value_x
# 1          QB         K        INT      Fantasy Score    0.259
# 237        QB        WR        INT        Rec Targets    0.084
# 42         QB        RB        INT        Rec Targets    0.070
# 165        QB        TE        INT        Rec Targets    0.061
# 44         QB        RB        INT         Receptions    0.049
# 43         QB        RB        INT    Receiving Yards    0.024
# 167        QB        TE        INT         Receptions    0.022
# 38         QB        RB        INT       Fumbles Lost    0.017
# 239        QB        WR        INT         Receptions    0.016
# 37         QB        RB        INT            Fumbles    0.011
# 238        QB        WR        INT    Receiving Yards    0.004
# 166        QB        TE        INT    Receiving Yards    0.001
# 241        QB        WR        INT       Rush+Rec Yds    0.001
# 169        QB        TE        INT       Rush+Rec Yds   -0.000
# 39         QB        RB        INT  Longest Reception   -0.009
# 234        QB        WR        INT      Fantasy Score   -0.014
# 162        QB        TE        INT      Fantasy Score   -0.016
# 235        QB        WR        INT  Longest Reception   -0.019
# 163        QB        TE        INT  Longest Reception   -0.023
# 41         QB        RB        INT            Rec TDs   -0.025
# 49         QB        RB        INT       Rush+Rec Yds   -0.039
# 236        QB        WR        INT            Rec TDs   -0.044
# 240        QB        WR        INT       Rush+Rec TDs   -0.046
# 164        QB        TE        INT            Rec TDs   -0.047
# 36         QB        RB        INT      Fantasy Score   -0.048
# 168        QB        TE        INT       Rush+Rec TDs   -0.049
# 40         QB        RB        INT       Longest Rush   -0.054
# 47         QB        RB        INT         Rush Yards   -0.059
# 45         QB        RB        INT      Rush Attempts   -0.059
# 46         QB        RB        INT           Rush TDs   -0.079
# 48         QB        RB        INT       Rush+Rec TDs   -0.080
# 0          QB         K        INT                 FG   -0.131
# 3          QB         K        INT                XPM   -0.189
# 2          QB         K        INT     Kicking Points   -0.203

# %%
pos_corr.loc[pos_corr.variable_y == "Rec Targets"].sort_values(by='value_x',ascending=False).head(30)
# Out:
#     FantPos_x FantPos_y        variable_x   variable_y  value_x
# 253        QB        WR     Pass Attempts  Rec Targets    0.199
# 84         QB        RB  Pass Completions  Rec Targets    0.183
# 70         QB        RB     Pass Attempts  Rec Targets    0.178
# 261        QB        WR  Pass Completions  Rec Targets    0.174
# 277        QB        WR        Pass Yards  Rec Targets    0.152
# 181        QB        TE     Pass Attempts  Rec Targets    0.149
# 189        QB        TE  Pass Completions  Rec Targets    0.139
# 112        QB        RB        Pass Yards  Rec Targets    0.112
# 205        QB        TE        Pass Yards  Rec Targets    0.110
# 237        QB        WR               INT  Rec Targets    0.084
# 42         QB        RB               INT  Rec Targets    0.070
# 165        QB        TE               INT  Rec Targets    0.061
# 269        QB        WR          Pass TDs  Rec Targets    0.055
# 154        QB        RB      Yards Sacked  Rec Targets    0.044
# 140        QB        RB             Sacks  Rec Targets    0.042
# 750        WR        RB       Rec Targets  Rec Targets    0.041
# 197        QB        TE          Pass TDs  Rec Targets    0.037
# 778        WR        RB        Receptions  Rec Targets    0.031
# 245        QB        WR      Longest Pass  Rec Targets    0.025
# 301        QB        WR      Yards Sacked  Rec Targets    0.018
# 293        QB        WR             Sacks  Rec Targets    0.017
# 609        RB        TE       Rec Targets  Rec Targets    0.014
# 841        WR        TE       Rec Targets  Rec Targets    0.014
# 229        QB        TE      Yards Sacked  Rec Targets    0.012
# 221        QB        TE             Sacks  Rec Targets    0.011
# 764        WR        RB   Receiving Yards  Rec Targets    0.010
# 625        RB        TE        Receptions  Rec Targets    0.008
# 98         QB        RB          Pass TDs  Rec Targets    0.008
# 806        WR        RB      Rush+Rec Yds  Rec Targets    0.007
# 708        WR        RB     Fantasy Score  Rec Targets    0.004

# %%
current = players.loc[players.year==2024,['player','FantPos']]
nfl = pp.loc[(pp.event_time > '2024-10-10') & (pp.alt_line=='standard')]
nfl = nfl[['player','team','line','stat','opp','event_time']].merge(current)
pp_pairs = nfl.merge(nfl,on=['team','opp', 'event_time'])
pp_pairs = pp_pairs.loc[pp_pairs.player_x!=pp_pairs.player_y]
pp_pairs
# Out:
#                  player_x team  line_x        stat_x  opp  \
# 10     Kenneth Walker III  SEA   3.000    Receptions   SF
# 11     Kenneth Walker III  SEA   3.000    Receptions   SF
# 12     Kenneth Walker III  SEA   3.000    Receptions   SF
# 13     Kenneth Walker III  SEA   3.000    Receptions   SF
# 14     Kenneth Walker III  SEA   3.000    Receptions   SF
# ...                   ...  ...     ...           ...  ...
# 51927         Aaron Jones  MIN   0.500  Rush+Rec TDs  DET
# 51928         Aaron Jones  MIN   0.500  Rush+Rec TDs  DET
# 51929         Aaron Jones  MIN   0.500  Rush+Rec TDs  DET
# 51930         Aaron Jones  MIN   0.500  Rush+Rec TDs  DET
# 51931         Aaron Jones  MIN   0.500  Rush+Rec TDs  DET
#
#                      event_time FantPos_x      player_y  line_y  \
# 10    2024-10-10 18:00:00-06:00        RB    Geno Smith   0.500
# 11    2024-10-10 18:00:00-06:00        RB    Geno Smith  13.500
# 12    2024-10-10 18:00:00-06:00        RB    Geno Smith   9.500
# 13    2024-10-10 18:00:00-06:00        RB    Geno Smith   3.000
# 14    2024-10-10 18:00:00-06:00        RB    Geno Smith  23.500
# ...                         ...       ...           ...     ...
# 51927 2024-10-20 11:00:00-06:00        RB   Sam Darnold  17.500
# 51928 2024-10-20 11:00:00-06:00        RB  Johnny Mundt  11.500
# 51929 2024-10-20 11:00:00-06:00        RB  Johnny Mundt  17.500
# 51930 2024-10-20 11:00:00-06:00        RB  Johnny Mundt   2.000
# 51931 2024-10-20 11:00:00-06:00        RB  Johnny Mundt   2.500
#
#                   stat_y FantPos_y
# 10                   INT        QB
# 11            Rush Yards        QB
# 12          Longest Rush        QB
# 13         Rush Attempts        QB
# 14      Pass Completions        QB
# ...                  ...       ...
# 51927      Fantasy Score        QB
# 51928  Longest Reception        TE
# 51929    Receiving Yards        TE
# 51930         Receptions        TE
# 51931        Rec Targets        TE
#
# [42488 rows x 11 columns]

# %%
p1 = 'Bijan Robinson'
p2 = 'Tyler Allgeier'
s1 = 'Rush Attempts'
s2 = 'Rush Attempts'
out.loc[(out.player_1==p1)&
        (out.player_2==p2)&
        (out.stat_1==s1)&
        (out.stat_2==s2)]
# Out:
#                player_1        player_2 FantPos_1 FantPos_2         stat_1  \
# 2026225  Bijan Robinson  Tyler Allgeier        RB        RB  Rush Attempts
#
#                 stat_2   corr  gp  pos_corr  w_corr
# 2026225  Rush Attempts -0.327  23    -0.310  -0.319

# %%
pp_pairs.loc[(pp_pairs.player_x==p1)&
        (pp_pairs.player_y==p2)&
        (pp_pairs.stat_x==s1)&
        (pp_pairs.stat_y==s2)]
# Out:
# Empty DataFrame
# Columns: [player_x, team, line_x, stat_x, opp, event_time, FantPos_x, player_y, line_y, stat_y, FantPos_y]
# Index: []

# %%
pos_corr.loc[pos_corr.FantPos_x =='WR'].sort_values(by='value_x').head(60)
# Out:
#     FantPos_x FantPos_y         variable_x         variable_y  value_x
# 941        WR        WR       Rush+Rec Yds       Rush+Rec Yds   -0.062
# 937        WR        WR       Rush+Rec Yds        Rec Targets   -0.061
# 909        WR        WR        Rec Targets       Rush+Rec Yds   -0.061
# 917        WR        WR    Receiving Yards       Rush+Rec Yds   -0.060
# 938        WR        WR       Rush+Rec Yds    Receiving Yards   -0.060
# 881        WR        WR      Fantasy Score        Rec Targets   -0.060
# 902        WR        WR        Rec Targets      Fantasy Score   -0.060
# 694        WR         K       Rush+Rec TDs                 FG   -0.059
# 914        WR        WR    Receiving Yards    Receiving Yards   -0.058
# 678        WR         K            Rec TDs                 FG   -0.058
# 913        WR        WR    Receiving Yards        Rec Targets   -0.057
# 906        WR        WR        Rec Targets    Receiving Yards   -0.057
# 925        WR        WR         Receptions       Rush+Rec Yds   -0.056
# 939        WR        WR       Rush+Rec Yds         Receptions   -0.056
# 889        WR        WR  Longest Reception        Rec Targets   -0.054
# 903        WR        WR        Rec Targets  Longest Reception   -0.054
# 915        WR        WR    Receiving Yards         Receptions   -0.053
# 922        WR        WR         Receptions    Receiving Yards   -0.053
# 885        WR        WR      Fantasy Score       Rush+Rec Yds   -0.051
# 934        WR        WR       Rush+Rec Yds      Fantasy Score   -0.051
# 883        WR        WR      Fantasy Score         Receptions   -0.050
# 918        WR        WR         Receptions      Fantasy Score   -0.050
# 910        WR        WR    Receiving Yards      Fantasy Score   -0.049
# 882        WR        WR      Fantasy Score    Receiving Yards   -0.049
# 878        WR        WR      Fantasy Score      Fantasy Score   -0.049
# 923        WR        WR         Receptions         Receptions   -0.047
# 893        WR        WR  Longest Reception       Rush+Rec Yds   -0.047
# 935        WR        WR       Rush+Rec Yds  Longest Reception   -0.047
# 890        WR        WR  Longest Reception    Receiving Yards   -0.047
# 911        WR        WR    Receiving Yards  Longest Reception   -0.047
# 907        WR        WR        Rec Targets         Receptions   -0.047
# 921        WR        WR         Receptions        Rec Targets   -0.047
# 919        WR        WR         Receptions  Longest Reception   -0.046
# 891        WR        WR  Longest Reception         Receptions   -0.046
# 755        WR        RB        Rec Targets         Rush Yards   -0.044
# 685        WR         K        Rec Targets                XPM   -0.043
# 929        WR        WR       Rush+Rec TDs        Rec Targets   -0.040
# 908        WR        WR        Rec Targets       Rush+Rec TDs   -0.040
# 748        WR        RB        Rec Targets       Longest Rush   -0.039
# 905        WR        WR        Rec Targets        Rec Targets   -0.038
# 879        WR        WR      Fantasy Score  Longest Reception   -0.037
# 886        WR        WR  Longest Reception      Fantasy Score   -0.037
# 897        WR        WR            Rec TDs        Rec Targets   -0.037
# 904        WR        WR        Rec Targets            Rec TDs   -0.037
# 754        WR        RB        Rec Targets           Rush TDs   -0.033
# 756        WR        RB        Rec Targets       Rush+Rec TDs   -0.033
# 887        WR        WR  Longest Reception  Longest Reception   -0.032
# 742        WR        RB            Rec TDs       Rush+Rec TDs   -0.029
# 798        WR        RB       Rush+Rec TDs       Rush+Rec TDs   -0.029
# 836        WR        TE            Rec TDs       Rush+Rec TDs   -0.029
# 757        WR        RB        Rec Targets       Rush+Rec Yds   -0.029
# 868        WR        TE       Rush+Rec TDs       Rush+Rec TDs   -0.028
# 932        WR        WR       Rush+Rec TDs       Rush+Rec TDs   -0.028
# 776        WR        RB         Receptions       Longest Rush   -0.028
# 832        WR        TE            Rec TDs            Rec TDs   -0.027
# 864        WR        TE       Rush+Rec TDs            Rec TDs   -0.027
# 783        WR        RB         Receptions         Rush Yards   -0.026
# 753        WR        RB        Rec Targets      Rush Attempts   -0.025
# 900        WR        WR            Rec TDs       Rush+Rec TDs   -0.025
# 928        WR        WR       Rush+Rec TDs            Rec TDs   -0.025

# %%
small.head(5)
# Out:
#          player_x  snaps_x pct_x FantPos_x pos_x team  opp  home      roof  \
# 0  Peyton Manning   75.000  100%        QB    QB  DEN  IND     1  outdoors
# 1  Peyton Manning   75.000  100%        QB    QB  DEN  IND     1  outdoors
# 2  Peyton Manning   75.000  100%        QB    QB  DEN  IND     1  outdoors
# 3  Peyton Manning   75.000  100%        QB    QB  DEN  IND     1  outdoors
# 4  Peyton Manning   75.000  100%        QB    QB  DEN  IND     1  outdoors
#
#   surface  ...       date        variable_x value_x          player_y  \
# 0   grass  ... 2014-09-07  Pass Completions  22.000    Andre Caldwell
# 1   grass  ... 2014-09-07  Pass Completions  22.000  Demaryius Thomas
# 2   grass  ... 2014-09-07  Pass Completions  22.000  Emmanuel Sanders
# 3   grass  ... 2014-09-07  Pass Completions  22.000    Andre Caldwell
# 4   grass  ... 2014-09-07  Pass Completions  22.000  Demaryius Thomas
#
#    snaps_y pct_y FantPos_y  pos_y   variable_y  value_y
# 0   41.000   55%        WR     WR  Rec Targets    5.000
# 1   67.000   89%        WR     WR  Rec Targets   11.000
# 2   70.000   93%        WR     WR  Rec Targets    9.000
# 3   41.000   55%        WR     WR   Receptions    2.000
# 4   67.000   89%        WR     WR   Receptions    4.000
#
# [5 rows x 25 columns]

# %%
import pingouin as pg

def compute_partial_corr(group):
    return pg.partial_corr(data=group, x='value_x', y='value_y', covar='total')

# Apply the partial correlation computation for each player position
partial_corr_by_position = small.groupby(['FantPos_x','FantPos_y','variable_x','variable_y']).apply(compute_partial_corr)

# %%
partial_corr_by_position.sort_values(by='r')
# Out:
#                                                              n      r  \
# FantPos_x FantPos_y variable_x    variable_y
# QB        K         Yards Sacked  Fantasy Score pearson     12 -0.392
# RB        RB        Rush Attempts Rush Attempts pearson  19208 -0.311
# QB        K         Sacks         XPM           pearson   5743 -0.263
#                     Yards Sacked  XPM           pearson   5743 -0.248
# RB        RB        Rush Attempts Rush Yards    pearson  19208 -0.240
# ...                                                        ...    ...
# QB        WR        Pass TDs      Rush+Rec TDs  pearson  21562  0.298
#                                   Rec TDs       pearson  21562  0.307
#           K         Pass Yards    Fantasy Score pearson     12  0.367
#                     Pass TDs      XPM           pearson   5743  0.394
#                     Passing Rate  XPM           pearson   5506  0.458
#
#                                                                   CI95%  p-val
# FantPos_x FantPos_y variable_x    variable_y
# QB        K         Yards Sacked  Fantasy Score pearson    [-0.8, 0.27]  0.233
# RB        RB        Rush Attempts Rush Attempts pearson   [-0.32, -0.3]  0.000
# QB        K         Sacks         XPM           pearson  [-0.29, -0.24]  0.000
#                     Yards Sacked  XPM           pearson  [-0.27, -0.22]  0.000
# RB        RB        Rush Attempts Rush Yards    pearson  [-0.25, -0.23]  0.000
# ...                                                                 ...    ...
# QB        WR        Pass TDs      Rush+Rec TDs  pearson    [0.29, 0.31]  0.000
#                                   Rec TDs       pearson     [0.3, 0.32]  0.000
#           K         Pass Yards    Fantasy Score pearson    [-0.3, 0.79]  0.267
#                     Pass TDs      XPM           pearson    [0.37, 0.42]  0.000
#                     Passing Rate  XPM           pearson    [0.44, 0.48]  0.000
#
# [942 rows x 4 columns]

# %%
import statsmodels.api as sm

# X variables (Player B's stat and control variables)
X = small[['Player_B_stat', 'other_stat1', 'other_stat2']]
X = sm.add_constant(X)  # Adds a constant term to the model
y = small['Player_A_stat']  # Dependent variable (Player A's stat)

# Fit the regression model
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 4
#       1 import statsmodels.api as sm
#       3 # X variables (Player B's stat and control variables)
# ----> 4 X = small[['Player_B_stat', 'other_stat1', 'other_stat2']]
#       5 X = sm.add_constant(X)  # Adds a constant term to the model
#       6 y = small['Player_A_stat']  # Dependent variable (Player A's stat)
#
# File c:\Github\NBA_betting_model\.conda\Lib\site-packages\pandas\core\frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Github\NBA_betting_model\.conda\Lib\site-packages\pandas\core\indexes\base.py:6115, in Index._get_indexer_strict(self, key, axis_name)
#    6112 else:
#    6113     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6115 self._raise_if_missing(keyarr, indexer, axis_name)
#    6117 keyarr = self.take(indexer)
#    6118 if isinstance(key, Index):
#    6119     # GH 42790 - Preserve name from an Index
#
# File c:\Github\NBA_betting_model\.conda\Lib\site-packages\pandas\core\indexes\base.py:6176, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6174     if use_interval_msg:
#    6175         key = list(key)
# -> 6176     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6178 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6179 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['Player_B_stat', 'other_stat1', 'other_stat2'], dtype='object')] are in the [columns]"

# %%
common_cols
# Out:
# ['team',
#  'opp',
#  'home',
#  'roof',
#  'surface',
#  'weather',
#  'line',
#  'favored',
#  'total',
#  'season',
#  'date']

# %%
small.iloc[0]
# Out:
# player_x                                              Tom Brady
# snaps_x                                                    71.0
# pct_x                                                       89%
# FantPos_x                                                    QB
# pos_x                                                        QB
# team                                                         NE
# opp                                                         CLE
# home                                                          0
# roof                                                   outdoors
# surface                                                   grass
# weather       58 degrees, relative humidity 58%, wind 13 mph...
# line                                                      -10.0
# favored                                                      NE
# total                                                      47.5
# season                                                     2016
# date                                        2016-10-09 00:00:00
# variable_x                                     Pass Completions
# value_x                                                    28.0
# player_y                                         Julian Edelman
# snaps_y                                                    59.0
# pct_y                                                       74%
# FantPos_y                                                    WR
# pos_y                                                        WR
# variable_y                                          Rec Targets
# value_y                                                    10.0
# Name: 0, dtype: object

# %%
games[['team','opp','favored','line','total', 'date']]
# Out:
#        team  opp favored  line  total       date
# 0       CHI  MIN     MIN  -4.5   46.5 2000-09-03
# 1       CHI  TAM      TB  -7.0   36.5 2000-09-10
# 2       CHI  NYG     CHI  -2.0   42.0 2000-09-17
# 3       CHI  DET     CHI  -1.0   37.5 2000-09-24
# 4       CHI  GNB      GB  -5.5   41.0 2000-10-01
# ...     ...  ...     ...   ...    ...        ...
# 712902  CIN  KAN      KC  -6.0   48.0 2024-09-15
# 712903  CIN  WAS     CIN  -7.5   46.5 2024-09-23
# 712904  CIN  CAR     CIN  -4.5   47.0 2024-09-29
# 712905  HOU  CHI     HOU  -6.0   45.0 2024-09-15
# 712906  HOU  JAX     HOU  -5.5   44.5 2024-09-29
#
# [113707 rows x 6 columns]
